# %%
import json

# %%
with open('replay_parser/replay_data.json', 'r') as file:
    replay_data = json.load(file)

# %%
replay_data['properties']['Goals']
# Out:
# [{'frame': 699, 'PlayerName': 'KittyAction', 'PlayerTeam': 0},
#  {'frame': 1179, 'PlayerName': 'sharkyblan', 'PlayerTeam': 1},
#  {'frame': 2167, 'PlayerName': 'TT zerrpex', 'PlayerTeam': 0},
#  {'frame': 2803, 'PlayerName': 'TT zerrpex', 'PlayerTeam': 0},
#  {'frame': 4593, 'PlayerName': 'UnclearSquash54', 'PlayerTeam': 0},
#  {'frame': 5242, 'PlayerName': 'omarh8m', 'PlayerTeam': 1},
#  {'frame': 6287, 'PlayerName': 'omarh8m', 'PlayerTeam': 1},
#  {'frame': 8188, 'PlayerName': 'ily yaz', 'PlayerTeam': 1},
#  {'frame': 9160, 'PlayerName': 'TT zerrpex', 'PlayerTeam': 0},
#  {'frame': 10596, 'PlayerName': 'ily yaz', 'PlayerTeam': 1},
#  {'frame': 11012, 'PlayerName': 'UnclearSquash54', 'PlayerTeam': 0}]

# %%
replay_data['objects'][275]
# Out:
# 'TAGame.Vehicle_TA:bDriving'

# %%
replay_data['objects'].index('TAGame.Car_TA')
# Out:
# 292

# %%
replay_data['network_frames']['frames'][2931]
# Out:
# {'time': 124.90641,
#  'delta': 0.0333338,
#  'new_actors': [],
#  'deleted_actors': [],
#  'updated_actors': [{'actor_id': 125,
#    'stream_id': 51,
#    'object_id': 271,
#    'attribute': {'Byte': 241}}]}

# %%
replay_data['network_frames']['frames'][2976]
# Out:
# {'time': 126.40606,
#  'delta': 0.033334,
#  'new_actors': [],
#  'deleted_actors': [],
#  'updated_actors': [{'actor_id': 249,
#    'stream_id': 50,
#    'object_id': 270,
#    'attribute': {'Byte': 128}},
#   {'actor_id': 125,
#    'stream_id': 51,
#    'object_id': 271,
#    'attribute': {'Byte': 249}}]}

# %%
FIVE_SECONDS = int(replay_data['properties']['RecordFPS'] * 5) + 5 # Some extra frames for interpolation
FIVE_SECONDS
# Out:
# 155

# %%
def name_to_id(name: str) -> int:
    if name == 'None':
        raise ValueError('Name is None')
    return replay_data['names'].index(name)

# %%
keyframes = [keyframe_data['frame'] for keyframe_data in replay_data['keyframes']]

# %%
def to_recent_keyframe(frame: int) -> int:
    return min(keyframes, key=lambda keyframe: frame - keyframe if keyframe <= frame else float('inf'))

# %%
goals = [highlight for highlight in replay_data['properties']['HighLights'] if highlight['GoalActorName'] != 'None']
goals
# Out:
# [{'frame': 699,
#   'CarName': 'Car_TA_261',
#   'BallName': 'None',
#   'GoalActorName': 'GoalVolume_TA_4'},
#  {'frame': 1179,
#   'CarName': 'Car_TA_275',
#   'BallName': 'None',
#   'GoalActorName': 'GoalVolume_TA_0'},
#  {'frame': 2167,
#   'CarName': 'Car_TA_288',
#   'BallName': 'Ball_TA_46',
#   'GoalActorName': 'GoalVolume_TA_4'},
#  {'frame': 2803,
#   'CarName': 'Car_TA_301',
#   'BallName': 'Ball_TA_48',
#   'GoalActorName': 'GoalVolume_TA_4'},
#  {'frame': 4593,
#   'CarName': 'Car_TA_313',
#   'BallName': 'Ball_TA_50',
#   'GoalActorName': 'GoalVolume_TA_4'},
#  {'frame': 5242,
#   'CarName': 'Car_TA_331',
#   'BallName': 'Ball_TA_52',
#   'GoalActorName': 'GoalVolume_TA_0'},
#  {'frame': 6287,
#   'CarName': 'Car_TA_350',
#   'BallName': 'Ball_TA_54',
#   'GoalActorName': 'GoalVolume_TA_0'},
#  {'frame': 8188,
#   'CarName': 'Car_TA_363',
#   'BallName': 'Ball_TA_56',
#   'GoalActorName': 'GoalVolume_TA_0'},
#  {'frame': 9160,
#   'CarName': 'Car_TA_376',
#   'BallName': 'Ball_TA_58',
#   'GoalActorName': 'GoalVolume_TA_4'},
#  {'frame': 10596,
#   'CarName': 'Car_TA_393',
#   'BallName': 'Ball_TA_58',
#   'GoalActorName': 'GoalVolume_TA_0'},
#  {'frame': 11012,
#   'CarName': 'Car_TA_403',
#   'BallName': 'Ball_TA_58',
#   'GoalActorName': 'GoalVolume_TA_4'}]

# %%
name_to_id(goals[0]['CarName'])
# Out:
# 27

# %%
goal_data = goals[0]

# %%
goal_data['frame'] - FIVE_SECONDS
# Out:
# 544

# %%
relevant_keyframes = [keyframe for keyframe in keyframes if to_recent_keyframe(goal_data['frame'] - FIVE_SECONDS) <= keyframe <= goal_data['frame']]
relevant_keyframes
# Out:
# [300, 600]

# %%
def get_relevant_keyframes(goal_data: dict) -> list:
    return [keyframe for keyframe in keyframes if to_recent_keyframe(goal_data['frame'] - FIVE_SECONDS) <= keyframe <= goal_data['frame']]

# %%
ball_names = [x for x in replay_data['names'] if 'Ball' in x]
ball_idxs = [replay_data['names'].index(ball_name) for ball_name in ball_names]
ball_idxs
# Out:
# [2, 139, 181, 204, 247, 350, 412, 461, 518, 572, 597, 666]

# %%
def handle_ball_error(keyframe: int, goal_data: dict) -> int:
    possible_ball_idx = []
    for actor in replay_data['network_frames']['frames'][keyframe]['new_actors']:
        if actor['name_id'] in ball_idxs:
            possible_ball_idx.append(actor['name_id'])
    if len(possible_ball_idx) == 1:
        return possible_ball_idx[0]
    else:
        raise ValueError('Multiple balls found')

# %%
# THIS REQUIRES THE LIST `keyframes` TO EXIST

def get_actors(keyframe: int, goal_data: dict) -> dict:
    """Get the actors for a given keyframe for the ball and scorer name

    Args:
        keyframe (int): A keyframe
        goal_data (dict): The goal data
    Returns:
        dict: ball and car actor idds
    """
    if keyframe not in keyframes:
        raise ValueError('Keyframe not in keyframes')
    actors = {}
    # Check actor_id when keyframe regenerates actor_ids
    new_actors = replay_data['network_frames']['frames'][keyframe]['new_actors']
    for actor in new_actors:
        try:
            ball_id = name_to_id(goal_data['BallName'])
        except ValueError:
            ball_id = handle_ball_error(keyframe, goal_data)
        car_id = name_to_id(goal_data['CarName'])
        if actor['name_id'] == ball_id:
            actors['ball'] = actor['actor_id']
        elif actor['name_id'] == car_id:
            actors['car'] = actor['actor_id']
            
    # handle ball error
    if 'ball' not in actors:
        ball_id = handle_ball_error(keyframe, goal_data)
        for actor in new_actors:
            if actor['name_id'] == ball_id:
                actors['ball'] = actor['actor_id']
    
    # final error check
    if 'ball' not in actors:
        raise ValueError('Ball not found')
    elif 'car' not in actors:
        raise ValueError('Car not found')
    return actors

# %%
actors = {}
for keyframe in relevant_keyframes:
    actors[keyframe] = get_actors(keyframe, goal_data)
actors
# Out:
# {300: {'ball': 2, 'car': 27}, 600: {'ball': 2, 'car': 27}}

# %%
def get_carball_data(actor_data: list, actors: dict) -> dict:
    output = {}
    for actor in actor_data:
        if actor['actor_id'] == actors['ball']:
            try:
                output['ball'] = actor['attribute']['RigidBody']
            except KeyError: # Sometimes the attribute being updated isn't the rigid body
                continue
        elif actor['actor_id'] == actors['car']:
            try:
                output['car'] = actor['attribute']['RigidBody']
            except KeyError:
                continue
            
    return output

# %%
def interpolate_missing_data(goal_snippet_data: dict) -> dict:
    """Interpolate missing car and ball data between known points.
    Handles:
    - Kickoff positions for ball and car at start
    - Normal interpolation between known points
    - Demolished car state for large gaps at end
    """
    interpolated_data = goal_snippet_data.copy()
    max_frame = FIVE_SECONDS
    
    # Default values
    KICKOFF_BALL_DATA = {
        'sleeping': False,
        'location': {'x': 0, 'y': 0, 'z': 110},
        'rotation': {'x': 0, 'y': 0, 'z': 0, 'w': 1},
        'linear_velocity': {'x': 0, 'y': 0, 'z': 0},
        'angular_velocity': {'x': 0, 'y': 0, 'z': 0}
    }
    
    KICKOFF_CAR_DATA = {
        'sleeping': False,
        'location': {
            'x': 2160.300000000003,
            'y': 2672.3000000000175,
            'z': 17.00999999999999
        },
        'rotation': {
            'x': -0.00538131,
            'y': -0.0018153489999999939,
            'z': 0.9238633999999948,
            'w': -0.38268401999999924
        },
        'linear_velocity': {
            'x': 2624.95,
            'y': 2624.95,
            'z': 3.7300000000000004
        },
        'angular_velocity': {
            'x': 0.3400000000000001,
            'y': 0.050000000000000044,
            'z': 0.0
        }
    }
    
    DEMOLISHED_CAR_DATA = KICKOFF_CAR_DATA.copy()
    DEMOLISHED_CAR_DATA['sleeping'] = True
    
    # Normal interpolation
    for entity in ['car', 'ball']:
        known_frames = [
            frame for frame, data in goal_snippet_data.items() 
            if entity in data
        ]
        
        if not known_frames:
            continue
            
        # Interpolate between known frames
        for i in range(len(known_frames) - 1):
            start_frame = known_frames[i]
            end_frame = known_frames[i + 1]
            frame_gap = end_frame - start_frame
            
            if frame_gap <= 1:
                continue
            
            if entity == 'car' and frame_gap > 10:
                # Use the next known position (post-respawn) with sleeping=True
                demolished_car_data = goal_snippet_data[end_frame]['car'].copy()
                demolished_car_data['sleeping'] = True
                
                # Fill in all frames in the gap
                for frame in range(start_frame + 1, end_frame):
                    if frame not in interpolated_data:
                        interpolated_data[frame] = {}
                    interpolated_data[frame]['car'] = demolished_car_data.copy()
            else:
                start_data = goal_snippet_data[start_frame][entity]
                end_data = goal_snippet_data[end_frame][entity]
                
                for frame in range(start_frame + 1, end_frame):
                    t = (frame - start_frame) / frame_gap
                    if frame not in interpolated_data:
                        interpolated_data[frame] = {}
                    
                    interpolated_data[frame][entity] = interpolate_attributes(start_data, end_data, t)
        
        # Handle end frames
        min_frame = min(goal_snippet_data.keys())
        if entity == 'car':
            # Check remaining frames after interpolation
            remaining_frames = [
                f for f in range(min_frame, max_frame)
                if f not in interpolated_data or 'car' not in interpolated_data[f]
            ]
            if len(remaining_frames) >= 10:  # Car was likely demolished
                # Find the first frame where we have car data (closest to goal)
                first_car_frame = known_frames[0]
                demolished_car_data = goal_snippet_data[first_car_frame]['car'].copy()
                demolished_car_data['sleeping'] = True  # Mark as demolished
                
                # Copy this data to all remaining frames
                for frame in remaining_frames:
                    if frame not in interpolated_data:
                        interpolated_data[frame] = {}
                    interpolated_data[frame]['car'] = demolished_car_data.copy()
            elif len(known_frames) >= 2:  # Normal extrapolation for short gaps
                last_frame = known_frames[-1]
                second_last_frame = known_frames[-2]
                frame_gap = last_frame - second_last_frame
                
                last_data = goal_snippet_data[last_frame]['car']
                second_last_data = goal_snippet_data[second_last_frame]['car']
                
                for frame in remaining_frames:
                    t = (frame - last_frame) / frame_gap
                    if frame not in interpolated_data:
                        interpolated_data[frame] = {}
                    interpolated_data[frame]['car'] = interpolate_attributes(second_last_data, last_data, 1 + t)
        
        else:  # Normal extrapolation for ball
            remaining_frames = [
                f for f in range(min_frame, max_frame)
                if f not in interpolated_data or 'ball' not in interpolated_data[f]
            ]
            
            if remaining_frames and len(known_frames) >= 2:
                last_frame = known_frames[-1]
                second_last_frame = known_frames[-2]
                frame_gap = last_frame - second_last_frame
                
                last_data = goal_snippet_data[last_frame]['ball']
                second_last_data = goal_snippet_data[second_last_frame]['ball']
                
                for frame in remaining_frames:
                    t = (frame - last_frame) / frame_gap
                    if frame not in interpolated_data:
                        interpolated_data[frame] = {}
                    interpolated_data[frame]['ball'] = interpolate_attributes(second_last_data, last_data, 1 + t)
    
    # Handle kickoff positions
    early_frames = [f for f in goal_snippet_data.keys() if f <= 150]
    for entity, default_data in [('ball', KICKOFF_BALL_DATA), ('car', KICKOFF_CAR_DATA)]:
        empty_frames = [
            f for f in early_frames 
            if f not in goal_snippet_data or entity not in goal_snippet_data[f]
        ]
        
        if len(empty_frames) >= 10:
            for frame in empty_frames:
                if frame not in interpolated_data:
                    interpolated_data[frame] = {}
                interpolated_data[frame][entity] = default_data.copy()
                
    return interpolated_data

def interpolate_attributes(start_data: dict, end_data: dict, t: float) -> dict:
    """Helper function to interpolate/extrapolate between two data points.
    
    Args:
        start_data (dict): Starting point data
        end_data (dict): Ending point data
        t (float): Interpolation factor (0-1 for interpolation, >1 for extrapolation)
    """
    if start_data['sleeping']:
        return end_data
    return {
        'sleeping': False,
        'location': {
            'x': start_data['location']['x'] * (1-t) + end_data['location']['x'] * t,
            'y': start_data['location']['y'] * (1-t) + end_data['location']['y'] * t,
            'z': start_data['location']['z'] * (1-t) + end_data['location']['z'] * t
        },
        'rotation': {
            'x': start_data['rotation']['x'] * (1-t) + end_data['rotation']['x'] * t,
            'y': start_data['rotation']['y'] * (1-t) + end_data['rotation']['y'] * t,
            'z': start_data['rotation']['z'] * (1-t) + end_data['rotation']['z'] * t,
            'w': start_data['rotation']['w'] * (1-t) + end_data['rotation']['w'] * t
        },
        'linear_velocity': {
            'x': start_data['linear_velocity']['x'] * (1-t) + end_data['linear_velocity']['x'] * t,
            'y': start_data['linear_velocity']['y'] * (1-t) + end_data['linear_velocity']['y'] * t,
            'z': start_data['linear_velocity']['z'] * (1-t) + end_data['linear_velocity']['z'] * t
        },
        'angular_velocity': {
            'x': start_data['angular_velocity']['x'] * (1-t) + end_data['angular_velocity']['x'] * t,
            'y': start_data['angular_velocity']['y'] * (1-t) + end_data['angular_velocity']['y'] * t,
            'z': start_data['angular_velocity']['z'] * (1-t) + end_data['angular_velocity']['z'] * t
        }
    }

# %%
get_relevant_keyframes(goals[2])
# Out:
# [1868]

# %%
goals[2]['frame']
# Out:
# 2167

# %%
def build_dataset_goal(goal_data: dict) -> dict:
    """Builds the dataset for a given goal

    Args:
        goal_data (dict): Data from `goals`

    Returns:
        dict: _description_
    """
    relevant_keyframes = get_relevant_keyframes(goal_data)
    goal_snippet_data = {}
    straddles = len(relevant_keyframes) != 1
    actors = get_actors(relevant_keyframes[-1], goal_data)

    for distance in range(1, FIVE_SECONDS + 1):
        frame = goal_data['frame'] - distance
        if straddles:
            try:
                actors = get_actors(to_recent_keyframe(frame), goal_data)
            except ValueError:
                continue
                # raise ValueError('Failed to get actors')
        actor_data = replay_data['network_frames']['frames'][frame]['updated_actors']
        goal_snippet_data[distance] = get_carball_data(actor_data, actors)
    return goal_snippet_data

# %%
import numpy as np

# %%
def flatten_game_state(game_state):
    """
    Flatten the game state dictionary into a numpy array.
    For each frame, extracts:
    - Ball: location (3), rotation (4), linear_velocity (3), angular_velocity (3)
    - Car: location (3), rotation (4), linear_velocity (3), angular_velocity (3)
    - Ball sleeping (1)
    - Car sleeping (1)
    Total features per frame: 25
    """
    # Sort frames by frame number and get total count
    sorted_frames = sorted(game_state.items())
    n_frames = len(sorted_frames)
    n_features = 28
    
    # Initialize array with zeros
    flattened = np.zeros(n_frames * n_features, dtype=np.float32)
    
    for frame_idx, (_, frame_data) in enumerate(sorted_frames):
        ball_data = frame_data['ball']
        car_data = frame_data['car']
        
        feature_vector = []
        
        # Ball data
        feature_vector.append(float(ball_data['sleeping']))
        
        # Ball location
        loc = ball_data['location']
        feature_vector.extend([loc['x'], loc['y'], loc['z']])
        
        # Ball rotation
        rot = ball_data['rotation']
        feature_vector.extend([rot['x'], rot['y'], rot['z'], rot['w']])
        
        # Ball linear velocity
        lin_vel = ball_data['linear_velocity']
        feature_vector.extend([lin_vel['x'], lin_vel['y'], lin_vel['z']])
        
        # Ball angular velocity
        ang_vel = ball_data['angular_velocity']
        feature_vector.extend([ang_vel['x'], ang_vel['y'], ang_vel['z']])
        
        # Car data
        feature_vector.append(float(car_data['sleeping']))
        
        # Car location
        loc = car_data['location']
        feature_vector.extend([loc['x'], loc['y'], loc['z']])
        
        # Car rotation
        rot = car_data['rotation']
        feature_vector.extend([rot['x'], rot['y'], rot['z'], rot['w']])
        
        # Car linear velocity
        lin_vel = car_data['linear_velocity']
        if lin_vel is not None:
            feature_vector.extend([lin_vel['x'], lin_vel['y'], lin_vel['z']])
        else:
            feature_vector.extend([0.0, 0.0, 0.0])
        
        # Car angular velocity
        ang_vel = car_data['angular_velocity']
        if ang_vel is not None:
            feature_vector.extend([ang_vel['x'], ang_vel['y'], ang_vel['z']])
        else:
            feature_vector.extend([0.0, 0.0, 0.0])
        
        # Assign the feature vector to the frame
        flattened[frame_idx * n_features:(frame_idx + 1) * n_features] = feature_vector
    
    return flattened

# %%
t = build_dataset_goal(goals[1])
# t = interpolate_missing_data(t)
# t = {f: t[f] for f in t.keys() if not f % 5 and f <= 150}
# flatten_game_state(t)
t
# Out:
# {1: {'ball': {'sleeping': False,
#    'location': {'x': -130.87, 'y': -5186.66, 'z': 377.84},
#    'rotation': {'x': -0.08399462,
#     'y': 0.05794846,
#     'z': 0.874503,
#     'w': 0.47416392},
#    'linear_velocity': {'x': 1934.15, 'y': -2071.2, 'z': 238.43},
#    'angular_velocity': {'x': -318.3, 'y': 224.35, 'z': 389.15}},
#   'car': {'sleeping': False,
#    'location': {'x': -247.75, 'y': -5024.59, 'z': 324.22},
#    'rotation': {'x': -0.102218285,
#     'y': -0.10510454,
#     'z': -0.50604194,
#     'w': 0.8499565},
#    'linear_velocity': {'x': 1349.94, 'y': -1730.92, 'z': 57.91},
#    'angular_velocity': {'x': -245.11, 'y': -23.02, 'z': -327.44}}},
#  2: {'ball': {'sleeping': False,
#    'location': {'x': -211.5, 'y': -5100.32, 'z': 367.45},
#    'rotation': {'x': -0.0881648,
#     'y': -0.015620676,
#     'z': 0.83031607,
#     'w': 0.5500529},
#    'linear_velocity': {'x': 1936.65, 'y': -2073.85, 'z': 265.86},
#    'angular_velocity': {'x': -318.3, 'y': 224.35, 'z': 389.15}}},
#  3: {'ball': {'sleeping': False,
#    'location': {'x': -283.3, 'y': -5047.37, 'z': 353.27},
#    'rotation': {'x': -0.15787661,
#     'y': -0.08513832,
#     'z': 0.7999507,
#     'w': 0.57263017},
#    'linear_velocity': {'x': 1055.14, 'y': -325.45, 'z': 328.18},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}},
#   'car': {'sleeping': False,
#    'location': {'x': -371.7, 'y': -4865.07, 'z': 317.64},
#    'rotation': {'x': -0.020551562,
#     'y': -0.08263509,
#     'z': -0.4039558,
#     'w': 0.91080666},
#    'linear_velocity': {'x': 1395.61, 'y': -1826.2, 'z': 85.03},
#    'angular_velocity': {'x': 137.68, 'y': 99.6, 'z': -107.18}}},
#  4: {'ball': {'sleeping': False,
#    'location': {'x': -318.49, 'y': -5036.53, 'z': 342.06},
#    'rotation': {'x': -0.24678859,
#     'y': -0.11826249,
#     'z': 0.7948567,
#     'w': 0.54158306},
#    'linear_velocity': {'x': 1056.22, 'y': -325.81, 'z': 350.22},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}}},
#  5: {'ball': {'sleeping': False,
#    'location': {'x': -344.9, 'y': -5028.37, 'z': 333.17},
#    'rotation': {'x': -0.31189865,
#     'y': -0.14234495,
#     'z': 0.78581977,
#     'w': 0.5147276},
#    'linear_velocity': {'x': 1057.03, 'y': -326.08, 'z': 366.75},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}}},
#  6: {'ball': {'sleeping': False,
#    'location': {'x': -380.15, 'y': -5017.49, 'z': 320.67},
#    'rotation': {'x': -0.39591753,
#     'y': -0.17319253,
#     'z': 0.76691335,
#     'w': 0.47444445},
#    'linear_velocity': {'x': 1058.11, 'y': -326.44, 'z': 388.83},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}},
#   'car': {'sleeping': False,
#    'location': {'x': -476.5, 'y': -4727.47, 'z': 310.05},
#    'rotation': {'x': -0.04249768,
#     'y': -0.12403493,
#     'z': -0.3681828,
#     'w': 0.9204622},
#    'linear_velocity': {'x': 1386.98, 'y': -1830.85, 'z': 119.3},
#    'angular_velocity': {'x': 64.61, 'y': 39.54, 'z': -72.13}}},
#  7: {'ball': {'sleeping': False,
#    'location': {'x': -397.79, 'y': -5012.05, 'z': 314.14},
#    'rotation': {'x': -0.43649736,
#     'y': -0.18798509,
#     'z': 0.75457066,
#     'w': 0.45249835},
#    'linear_velocity': {'x': 1058.65, 'y': -326.62, 'z': 399.87},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}}},
#  8: {'ball': {'sleeping': False,
#    'location': {'x': -424.26, 'y': -5003.89, 'z': 304.01},
#    'rotation': {'x': -0.49528468,
#     'y': -0.20928384,
#     'z': 0.73253214,
#     'w': 0.41748062},
#    'linear_velocity': {'x': 1059.46, 'y': -326.89, 'z': 416.44},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}}},
#  9: {'ball': {'sleeping': False,
#    'location': {'x': -459.59, 'y': -4992.99, 'z': 289.85},
#    'rotation': {'x': -0.5692908,
#     'y': -0.23583172,
#     'z': 0.69676006,
#     'w': 0.36717397},
#    'linear_velocity': {'x': 1060.54, 'y': -327.25, 'z': 438.56},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}},
#   'car': {'sleeping': False,
#    'location': {'x': -603.48, 'y': -4558.69, 'z': 297.48},
#    'rotation': {'x': -0.04868551,
#     'y': -0.13314138,
#     'z': -0.35155597,
#     'w': 0.925371},
#    'linear_velocity': {'x': 1371.63, 'y': -1839.54, 'z': 157.17},
#    'angular_velocity': {'x': -22.31, 'y': -23.65, 'z': 3.26}}},
#  10: {'ball': {'sleeping': False,
#    'location': {'x': -521.5, 'y': -4973.88, 'z': 263.3},
#    'rotation': {'x': 0.68469846,
#     'y': 0.27647093,
#     'z': -0.6176715,
#     'w': -0.27061749},
#    'linear_velocity': {'x': 1062.43, 'y': -327.88, 'z': 477.32},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}}},
#  11: {'ball': {'sleeping': False,
#    'location': {'x': -539.21, 'y': -4968.42, 'z': 255.3},
#    'rotation': {'x': 0.7139704,
#     'y': 0.28658077,
#     'z': -0.5914851,
#     'w': -0.2413776},
#    'linear_velocity': {'x': 1062.97, 'y': -328.06, 'z': 488.4},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}},
#   'car': {'sleeping': False,
#    'location': {'x': -706.25, 'y': -4420.0, 'z': 284.57},
#    'rotation': {'x': -0.03912593,
#     'y': -0.10995447,
#     'z': -0.35715038,
#     'w': 0.92672694},
#    'linear_velocity': {'x': 1357.77, 'y': -1846.61, 'z': 190.89},
#    'angular_velocity': {'x': -75.22, 'y': -79.89, 'z': 8.69}}},
#  12: {'ball': {'sleeping': False,
#    'location': {'x': -592.39, 'y': -4952.0, 'z': 230.18},
#    'rotation': {'x': 0.7908031,
#     'y': 0.31250826,
#     'z': -0.504348,
#     'w': -0.15034008},
#    'linear_velocity': {'x': 1064.59, 'y': -328.6, 'z': 521.7},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}}},
#  13: {'ball': {'sleeping': False,
#    'location': {'x': -619.01, 'y': -4943.78, 'z': 217.0},
#    'rotation': {'x': 0.8226502,
#     'y': 0.32287714,
#     'z': -0.45639884,
#     'w': -0.10342672},
#    'linear_velocity': {'x': 1065.4, 'y': -328.87, 'z': 538.37},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}},
#   'car': {'sleeping': False,
#    'location': {'x': -807.94, 'y': -4280.81, 'z': 268.87},
#    'rotation': {'x': -0.0203034,
#     'y': -0.06180574,
#     'z': -0.3604304,
#     'w': 0.9305148},
#    'linear_velocity': {'x': 1342.94, 'y': -1852.73, 'z': 232.09},
#    'angular_velocity': {'x': -112.14, 'y': -122.53, 'z': 2.11}}},
#  14: {'ball': {'sleeping': False,
#    'location': {'x': -654.54, 'y': -4932.82, 'z': 198.77},
#    'rotation': {'x': 0.85789675,
#     'y': 0.33386093,
#     'z': -0.38852122,
#     'w': -0.04001607},
#    'linear_velocity': {'x': 1066.48, 'y': -329.23, 'z': 560.61},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}},
#   'car': {'sleeping': False,
#    'location': {'x': -830.39, 'y': -4249.82, 'z': 264.95},
#    'rotation': {'x': -0.01523225,
#     'y': -0.048771825,
#     'z': -0.3609375,
#     'w': 0.93118924},
#    'linear_velocity': {'x': 1339.42, 'y': -1853.93, 'z': 242.66},
#    'angular_velocity': {'x': -115.2, 'y': -125.61, 'z': 3.8}}},
#  15: {'ball': {'sleeping': False,
#    'location': {'x': -690.1, 'y': -4921.84, 'z': 179.81},
#    'rotation': {'x': 0.88457173,
#     'y': 0.34151077,
#     'z': -0.3167594,
#     'w': 0.023804624},
#    'linear_velocity': {'x': 1067.57, 'y': -329.59, 'z': 582.88},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}},
#   'car': {'sleeping': False,
#    'location': {'x': -908.48, 'y': -4141.21, 'z': 249.74},
#    'rotation': {'x': 0.0009306024,
#     'y': -0.0075338753,
#     'z': -0.36596552,
#     'w': 0.9305974},
#    'linear_velocity': {'x': 1326.52, 'y': -1857.34, 'z': 283.93},
#    'angular_velocity': {'x': -78.08, 'y': -83.2, 'z': 37.2}}},
#  16: {},
#  17: {'ball': {'sleeping': False,
#    'location': {'x': -752.43, 'y': -4902.59, 'z': 144.83},
#    'rotation': {'x': 0.90986925,
#     'y': 0.34666827,
#     'z': -0.18401453,
#     'w': 0.13452785},
#    'linear_velocity': {'x': 1069.53, 'y': -330.22, 'z': 621.9},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}}},
#  18: {'ball': {'sleeping': False,
#    'location': {'x': -797.02, 'y': -4888.84, 'z': 118.45},
#    'rotation': {'x': 0.9109337,
#     'y': 0.34386298,
#     'z': -0.08551056,
#     'w': 0.21129614},
#    'linear_velocity': {'x': 1070.93, 'y': -330.67, 'z': 649.81},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}},
#   'car': {'sleeping': False,
#    'location': {'x': -1029.64, 'y': -3970.29, 'z': 220.59},
#    'rotation': {'x': 0.0111808,
#     'y': 0.019057203,
#     'z': -0.3931554,
#     'w': 0.91920656},
#    'linear_velocity': {'x': 1306.57, 'y': -1858.69, 'z': 357.94},
#    'angular_velocity': {'x': 1.55, 'y': -4.28, 'z': 94.11}}},
#  19: {'ball': {'sleeping': False,
#    'location': {'x': -814.87, 'y': -4883.32, 'z': 107.57},
#    'rotation': {'x': 0.90737504,
#     'y': 0.34123024,
#     'z': -0.04564824,
#     'w': 0.24114025},
#    'linear_velocity': {'x': 1071.49, 'y': -330.85, 'z': 660.99},
#    'angular_velocity': {'x': 173.58, 'y': 562.15, 'z': -117.69}}},
#  20: {'ball': {'sleeping': False,
#    'location': {'x': -853.17, 'y': -4872.51, 'z': 98.89},
#    'rotation': {'x': 0.8833802,
#     'y': 0.33881336,
#     'z': 0.04531376,
#     'w': 0.32061133},
#    'linear_velocity': {'x': 1381.82, 'y': -303.74, 'z': -1115.44},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -1138.29, 'y': -3815.02, 'z': 188.02},
#    'rotation': {'x': 0.0072640935,
#     'y': 0.012685948,
#     'z': -0.4348034,
#     'w': 0.9004067},
#    'linear_velocity': {'x': 1292.09, 'y': -1853.89, 'z': 428.42},
#    'angular_velocity': {'x': 21.26, 'y': 12.34, 'z': 119.97}}},
#  21: {'ball': {'sleeping': False,
#    'location': {'x': -933.84, 'y': -4854.79, 'z': 163.06},
#    'rotation': {'x': 0.800643,
#     'y': 0.3719214,
#     'z': 0.10855182,
#     'w': 0.45701388},
#    'linear_velocity': {'x': 1384.31, 'y': -304.3, 'z': -1079.5},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  22: {'ball': {'sleeping': False,
#    'location': {'x': -956.92, 'y': -4849.71, 'z': 181.01},
#    'rotation': {'x': 0.7723785,
#     'y': 0.37933385,
#     'z': 0.12609579,
#     'w': 0.49359608},
#    'linear_velocity': {'x': 1385.03, 'y': -304.46, 'z': -1069.22},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  23: {'ball': {'sleeping': False,
#    'location': {'x': -1003.1, 'y': -4839.55, 'z': 216.39},
#    'rotation': {'x': 0.71013707,
#     'y': 0.3912942,
#     'z': 0.16019098,
#     'w': 0.562968},
#    'linear_velocity': {'x': 1386.47, 'y': -304.78, 'z': -1048.64},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -1234.63, 'y': -3676.65, 'z': 153.95},
#    'rotation': {'x': 0.0035201048,
#     'y': 0.0062067136,
#     'z': -0.4669133,
#     'w': 0.8842743},
#    'linear_velocity': {'x': 1276.06, 'y': -1833.48, 'z': 482.17},
#    'angular_velocity': {'x': 10.76, 'y': 6.25, 'z': 58.64}}},
#  24: {'ball': {'sleeping': False,
#    'location': {'x': -1037.77, 'y': -4831.93, 'z': 242.48},
#    'rotation': {'x': 0.65876555,
#     'y': 0.39770323,
#     'z': 0.18473199,
#     'w': 0.611338},
#    'linear_velocity': {'x': 1387.55, 'y': -305.02, 'z': -1033.19},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  25: {'ball': {'sleeping': False,
#    'location': {'x': -1084.04, 'y': -4821.77, 'z': 276.66},
#    'rotation': {'x': 0.58455807,
#     'y': 0.40276355,
#     'z': 0.21581158,
#     'w': 0.6704467},
#    'linear_velocity': {'x': 1388.99, 'y': -305.34, 'z': -1012.58},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  26: {'ball': {'sleeping': False,
#    'location': {'x': -1153.54, 'y': -4806.48, 'z': 326.65},
#    'rotation': {'x': 0.4625489,
#     'y': 0.4028013,
#     'z': 0.25829577,
#     'w': 0.74637985},
#    'linear_velocity': {'x': 1391.15, 'y': -305.82, 'z': -981.62},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -1372.67, 'y': -3478.32, 'z': 98.19},
#    'rotation': {'x': 0.0023278547,
#     'y': 0.004172875,
#     'z': -0.47518897,
#     'w': 0.8798708},
#    'linear_velocity': {'x': 1272.14, 'y': -1827.5, 'z': 552.76},
#    'angular_velocity': {'x': 0.0, 'y': 0.0, 'z': -8.59}}},
#  27: {},
#  28: {'ball': {'sleeping': False,
#    'location': {'x': -1234.75, 'y': -4788.63, 'z': 383.0},
#    'rotation': {'x': 0.3072807,
#     'y': 0.39142367,
#     'z': 0.30046707,
#     'w': 0.81368643},
#    'linear_velocity': {'x': 1393.67, 'y': -306.38, 'z': -945.44},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -1468.51, 'y': -3340.65, 'z': 59.71},
#    'rotation': {'x': 0.0023278547,
#     'y': 0.004172875,
#     'z': -0.47215706,
#     'w': 0.8815015},
#    'linear_velocity': {'x': 1300.47, 'y': -1867.75, 'z': 325.11},
#    'angular_velocity': {'x': 0.0, 'y': 0.0, 'z': -9.97}}},
#  29: {'ball': {'sleeping': False,
#    'location': {'x': -1281.22, 'y': -4778.43, 'z': 414.26},
#    'rotation': {'x': 0.2140205,
#     'y': 0.37952268,
#     'z': 0.32052502,
#     'w': 0.84108347},
#    'linear_velocity': {'x': 1395.11, 'y': -306.7, 'z': -924.73},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -1490.18, 'y': -3309.53, 'z': 54.25},
#    'rotation': {'x': 0.0023278547,
#     'y': 0.004172875,
#     'z': -0.47141796,
#     'w': 0.881897},
#    'linear_velocity': {'x': 1299.87, 'y': -1866.83, 'z': 335.97},
#    'angular_velocity': {'x': 0.0, 'y': -0.01, 'z': -10.31}}},
#  30: {'ball': {'sleeping': False,
#    'location': {'x': -1316.11, 'y': -4770.75, 'z': 437.25},
#    'rotation': {'x': 0.14262544,
#     'y': 0.3680965,
#     'z': 0.33347252,
#     'w': 0.8561303},
#    'linear_velocity': {'x': 1396.19, 'y': -306.94, 'z': -909.19},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  31: {'ball': {'sleeping': False,
#    'location': {'x': -1362.66, 'y': -4760.51, 'z': 467.3},
#    'rotation': {'x': 0.046252456,
#     'y': 0.3496516,
#     'z': 0.34780657,
#     'w': 0.86869735},
#    'linear_velocity': {'x': 1397.63, 'y': -307.26, 'z': -888.45},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -1587.77, 'y': -3169.37, 'z': 29.47},
#    'rotation': {'x': 0.002295486,
#     'y': 0.004199849,
#     'z': -0.46777648,
#     'w': 0.8838338},
#    'linear_velocity': {'x': 1305.57, 'y': -1868.56, 'z': 306.51},
#    'angular_velocity': {'x': 0.04, 'y': -0.08, 'z': -12.34}}},
#  32: {'ball': {'sleeping': False,
#    'location': {'x': -1420.93, 'y': -4747.71, 'z': 503.88},
#    'rotation': {'x': -0.07475329,
#     'y': 0.32171726,
#     'z': 0.36082962,
#     'w': 0.87218803},
#    'linear_velocity': {'x': 1399.43, 'y': -307.66, 'z': -862.5},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  33: {'ball': {'sleeping': False,
#    'location': {'x': -1467.59, 'y': -4737.46, 'z': 532.37},
#    'rotation': {'x': -0.1708026,
#     'y': 0.29572496,
#     'z': 0.36719555,
#     'w': 0.86518246},
#    'linear_velocity': {'x': 1400.87, 'y': -307.98, 'z': -841.7},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  34: {'ball': {'sleeping': False,
#    'location': {'x': -1514.3, 'y': -4727.18, 'z': 560.16},
#    'rotation': {'x': -0.26515257,
#     'y': 0.26678178,
#     'z': 0.36989835,
#     'w': 0.8495274},
#    'linear_velocity': {'x': 1402.31, 'y': -308.3, 'z': -820.9},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -1733.94, 'y': -2967.76, 'z': 17.01},
#    'rotation': {'x': 0.002166011,
#     'y': 0.004280771,
#     'z': -0.4546455,
#     'w': 0.8906596},
#    'linear_velocity': {'x': 1402.69, 'y': -1822.76, 'z': 0.01},
#    'angular_velocity': {'x': 0.15, 'y': -0.2, 'z': -63.56}}},
#  35: {'ball': {'sleeping': False,
#    'location': {'x': -1549.37, 'y': -4719.47, 'z': 580.55},
#    'rotation': {'x': -0.3342278,
#     'y': 0.24330355,
#     'z': 0.36949375,
#     'w': 0.8322076},
#    'linear_velocity': {'x': 1403.39, 'y': -308.54, 'z': -805.27},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  36: {'ball': {'sleeping': False,
#    'location': {'x': -1596.17, 'y': -4709.19, 'z': 607.13},
#    'rotation': {'x': -0.42333937,
#     'y': 0.2099042,
#     'z': 0.36573356,
#     'w': 0.8018497},
#    'linear_velocity': {'x': 1404.83, 'y': -308.86, 'z': -784.43},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -1842.31, 'y': -2832.82, 'z': 17.01},
#    'rotation': {'x': 0.0020581149,
#     'y': 0.004334719,
#     'z': -0.42682442,
#     'w': 0.9043218},
#    'linear_velocity': {'x': 1489.0, 'y': -1752.96, 'z': 0.0},
#    'angular_velocity': {'x': -0.2, 'y': 0.24, 'z': -65.0}}},
#  37: {'ball': {'sleeping': False,
#    'location': {'x': -1654.74, 'y': -4696.31, 'z': 639.38},
#    'rotation': {'x': -0.5286786,
#     'y': 0.1652459,
#     'z': 0.35589337,
#     'w': 0.7526836},
#    'linear_velocity': {'x': 1406.63, 'y': -309.26, 'z': -758.34},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -1854.76, 'y': -2818.16, 'z': 17.01},
#    'rotation': {'x': 0.0020581149,
#     'y': 0.004334719,
#     'z': -0.42437518,
#     'w': 0.9054737},
#    'linear_velocity': {'x': 1497.9, 'y': -1745.35, 'z': 0.0},
#    'angular_velocity': {'x': -0.19, 'y': 0.23, 'z': -56.71}}},
#  38: {'ball': {'sleeping': False,
#    'location': {'x': -1701.64, 'y': -4685.99, 'z': 664.4},
#    'rotation': {'x': -0.6070815,
#     'y': 0.1276333,
#     'z': 0.34401944,
#     'w': 0.70484924},
#    'linear_velocity': {'x': 1408.07, 'y': -309.58, 'z': -737.45},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  39: {'ball': {'sleeping': False,
#    'location': {'x': -1748.59, 'y': -4675.67, 'z': 688.72},
#    'rotation': {'x': 0.67942244,
#     'y': -0.088736646,
#     'z': -0.32870892,
#     'w': -0.6499703},
#    'linear_velocity': {'x': 1409.51, 'y': -309.9, 'z': -716.53},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -1956.85, 'y': -2703.06, 'z': 17.01},
#    'rotation': {'x': 0.0020473253,
#     'y': 0.0043401136,
#     'z': -0.41345072,
#     'w': 0.9105139},
#    'linear_velocity': {'x': 1561.35, 'y': -1688.83, 'z': 0.0},
#    'angular_velocity': {'x': 0.05, 'y': -0.06, 'z': -30.8}}},
#  40: {'ball': {'sleeping': False,
#    'location': {'x': -1807.35, 'y': -4662.76, 'z': 718.14},
#    'rotation': {'x': 0.7602238,
#     'y': -0.038915534,
#     'z': -0.30496633,
#     'w': -0.5723119},
#    'linear_velocity': {'x': 1411.31, 'y': -310.3, 'z': -690.36},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  41: {'ball': {'sleeping': False,
#    'location': {'x': -1830.87, 'y': -4657.58, 'z': 729.6},
#    'rotation': {'x': 0.7892854,
#     'y': -0.018776674,
#     'z': -0.29411736,
#     'w': -0.5386752},
#    'linear_velocity': {'x': 1412.03, 'y': -310.46, 'z': -679.88},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -2077.37, 'y': -2578.87, 'z': 17.01},
#    'rotation': {'x': 0.0018369282,
#     'y': 0.004431825,
#     'z': -0.39427212,
#     'w': 0.9189812},
#    'linear_velocity': {'x': 1657.92, 'y': -1594.13, 'z': 0.02},
#    'angular_velocity': {'x': 0.36, 'y': -0.36, 'z': -105.94}}},
#  42: {'ball': {'sleeping': False,
#    'location': {'x': -1901.52, 'y': -4642.04, 'z': 762.94},
#    'rotation': {'x': 0.86436766,
#     'y': 0.04173162,
#     'z': -0.25727072,
#     'w': -0.43004516},
#    'linear_velocity': {'x': 1414.19, 'y': -310.94, 'z': -648.41},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  43: {'ball': {'sleeping': False,
#    'location': {'x': -1936.88, 'y': -4634.27, 'z': 779.02},
#    'rotation': {'x': 0.8947201,
#     'y': 0.07171598,
#     'z': -0.23662475,
#     'w': -0.37194297},
#    'linear_velocity': {'x': 1415.27, 'y': -311.18, 'z': -632.66},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  44: {'ball': {'sleeping': False,
#    'location': {'x': -2007.69, 'y': -4618.71, 'z': 809.99},
#    'rotation': {'x': 0.94018817,
#     'y': 0.13031451,
#     'z': -0.19145934,
#     'w': -0.24981512},
#    'linear_velocity': {'x': 1417.43, 'y': -311.66, 'z': -601.12},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -2235.14, 'y': -2438.17, 'z': 17.01},
#    'rotation': {'x': 0.0015563988,
#     'y': 0.004545116,
#     'z': -0.33921263,
#     'w': 0.94069743},
#    'linear_velocity': {'x': 1769.78, 'y': -1455.66, 'z': 0.02},
#    'angular_velocity': {'x': -0.28, 'y': 0.19, 'z': -86.25}}},
#  45: {'ball': {'sleeping': False,
#    'location': {'x': -2031.31, 'y': -4613.51, 'z': 819.97},
#    'rotation': {'x': 0.95068866,
#     'y': 0.14926112,
#     'z': -0.17539899,
#     'w': -0.20771936},
#    'linear_velocity': {'x': 1418.15, 'y': -311.82, 'z': -590.6},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  46: {'ball': {'sleeping': False,
#    'location': {'x': -2066.77, 'y': -4605.71, 'z': 834.6},
#    'rotation': {'x': 0.9619799,
#     'y': 0.1769635,
#     'z': -0.15049653,
#     'w': -0.14362891},
#    'linear_velocity': {'x': 1419.23, 'y': -312.06, 'z': -574.8},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -2367.32, 'y': -2332.11, 'z': 17.01},
#    'rotation': {'x': 0.0015563988,
#     'y': 0.004545116,
#     'z': -0.32907036,
#     'w': 0.9442932},
#    'linear_velocity': {'x': 1738.22, 'y': -1379.22, 'z': 0.01},
#    'angular_velocity': {'x': 0.04, 'y': -0.05, 'z': 0.06}}},
#  47: {'ball': {'sleeping': False,
#    'location': {'x': -2137.78, 'y': -4590.11, 'z': 862.68},
#    'rotation': {'x': 0.96830404,
#     'y': 0.22922844,
#     'z': -0.09829627,
#     'w': -0.01339802},
#    'linear_velocity': {'x': 1421.39, 'y': -312.54, 'z': -543.18},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  48: {'ball': {'sleeping': False,
#    'location': {'x': -2173.33, 'y': -4582.29, 'z': 876.13},
#    'rotation': {'x': 0.9632996,
#     'y': 0.2535051,
#     'z': -0.07129519,
#     'w': 0.052019496},
#    'linear_velocity': {'x': 1422.48, 'y': -312.78, 'z': -527.34},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  49: {'ball': {'sleeping': False,
#    'location': {'x': -2220.76, 'y': -4571.85, 'z': 893.44},
#    'rotation': {'x': 0.9482136,
#     'y': 0.28362983,
#     'z': -0.034691367,
#     'w': 0.13871421},
#    'linear_velocity': {'x': 1423.96, 'y': -313.1, 'z': -506.22},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -2523.67, 'y': -2208.02, 'z': 17.01},
#    'rotation': {'x': 0.0015563988,
#     'y': 0.004545116,
#     'z': -0.3291351,
#     'w': 0.9442706},
#    'linear_velocity': {'x': 1666.49, 'y': -1323.45, 'z': 0.01},
#    'angular_velocity': {'x': 0.04, 'y': -0.05, 'z': 0.28}}},
#  50: {'ball': {'sleeping': False,
#    'location': {'x': -2280.13, 'y': -4558.8, 'z': 914.09},
#    'rotation': {'x': 0.9160574,
#     'y': 0.31727186,
#     'z': 0.011504488,
#     'w': 0.24504067},
#    'linear_velocity': {'x': 1425.81, 'y': -313.5, 'z': -479.77},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  51: {'ball': {'sleeping': False,
#    'location': {'x': -2327.68, 'y': -4548.36, 'z': 929.82},
#    'rotation': {'x': 0.8800117,
#     'y': 0.34063682,
#     'z': 0.048361823,
#     'w': 0.32742494},
#    'linear_velocity': {'x': 1427.29, 'y': -313.82, 'z': -458.6},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  52: {'ball': {'sleeping': False,
#    'location': {'x': -2375.27, 'y': -4537.88, 'z': 944.84},
#    'rotation': {'x': 0.8351707,
#     'y': 0.36060303,
#     'z': 0.084739104,
#     'w': 0.4065399},
#    'linear_velocity': {'x': 1428.77, 'y': -314.14, 'z': -437.4},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -2673.4, 'y': -2088.97, 'z': 17.01},
#    'rotation': {'x': 0.001551004,
#     'y': 0.004545116,
#     'z': -0.32938325,
#     'w': 0.9441841},
#    'linear_velocity': {'x': 1593.24, 'y': -1269.62, 'z': 0.01},
#    'angular_velocity': {'x': 0.05, 'y': -0.05, 'z': 1.15}}},
#  53: {'ball': {'sleeping': False,
#    'location': {'x': -2411.0, 'y': -4530.02, 'z': 955.65},
#    'rotation': {'x': 0.79603744,
#     'y': 0.37322155,
#     'z': 0.11148659,
#     'w': 0.46325025},
#    'linear_velocity': {'x': 1429.88, 'y': -314.38, 'z': -421.49},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -2765.14, 'y': -2015.71, 'z': 17.01},
#    'rotation': {'x': 0.001551004,
#     'y': 0.004545116,
#     'z': -0.3298634,
#     'w': 0.94401646},
#    'linear_velocity': {'x': 1544.2, 'y': -1238.42, 'z': 0.01},
#    'angular_velocity': {'x': 0.05, 'y': -0.05, 'z': 2.79}}},
#  54: {'ball': {'sleeping': False,
#    'location': {'x': -2458.69, 'y': -4519.54, 'z': 969.43},
#    'rotation': {'x': 0.736937,
#     'y': 0.38677335,
#     'z': 0.14614293,
#     'w': 0.53476393},
#    'linear_velocity': {'x': 1431.36, 'y': -314.7, 'z': -400.25},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -2790.82, 'y': -1995.1, 'z': 17.01},
#    'rotation': {'x': 0.0015456092,
#     'y': 0.004545116,
#     'z': -0.33009538,
#     'w': 0.9439354},
#    'linear_velocity': {'x': 1529.48, 'y': -1230.39, 'z': 0.01},
#    'angular_velocity': {'x': 0.06, 'y': -0.05, 'z': 3.6}}},
#  55: {'ball': {'sleeping': False,
#    'location': {'x': -2506.42, 'y': -4509.06, 'z': 982.51},
#    'rotation': {'x': 0.6704773,
#     'y': 0.3964624,
#     'z': 0.17934799,
#     'w': 0.600926},
#    'linear_velocity': {'x': 1432.84, 'y': -315.02, 'z': -378.99},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  56: {'ball': {'sleeping': False,
#    'location': {'x': -2542.25, 'y': -4501.17, 'z': 991.85},
#    'rotation': {'x': 0.6161987,
#     'y': 0.40112892,
#     'z': 0.20309058,
#     'w': 0.6466444},
#    'linear_velocity': {'x': 1433.95, 'y': -315.26, 'z': -363.03},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  57: {'ball': {'sleeping': False,
#    'location': {'x': -2590.07, 'y': -4490.65, 'z': 1003.69},
#    'rotation': {'x': 0.5384917,
#     'y': 0.4038425,
#     'z': 0.23295094,
#     'w': 0.7019058},
#    'linear_velocity': {'x': 1435.43, 'y': -315.58, 'z': -341.74},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -2927.34, 'y': -1883.77, 'z': 17.01},
#    'rotation': {'x': 0.0015402144,
#     'y': 0.004545116,
#     'z': -0.3332891,
#     'w': 0.94281244},
#    'linear_velocity': {'x': 1436.27, 'y': -1201.38, 'z': 0.01},
#    'angular_velocity': {'x': 0.05, 'y': -0.04, 'z': 14.71}}},
#  58: {'ball': {'sleeping': False,
#    'location': {'x': -2673.87, 'y': -4472.24, 'z': 1022.69},
#    'rotation': {'x': 0.3900534,
#     'y': 0.39888468,
#     'z': 0.27943808,
#     'w': 0.78144974},
#    'linear_velocity': {'x': 1438.02, 'y': -316.14, 'z': -304.42},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  59: {'ball': {'sleeping': False,
#    'location': {'x': -2721.82, 'y': -4461.69, 'z': 1032.57},
#    'rotation': {'x': 0.29957694,
#     'y': 0.3905605,
#     'z': 0.30224735,
#     'w': 0.8163104},
#    'linear_velocity': {'x': 1439.5, 'y': -316.46, 'z': -283.06},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -3031.76, 'y': -1793.52, 'z': 17.01},
#    'rotation': {'x': 0.0016103467,
#     'y': 0.004528932,
#     'z': -0.3433774,
#     'w': 0.9391852},
#    'linear_velocity': {'x': 1330.5, 'y': -1212.69, 'z': 0.01},
#    'angular_velocity': {'x': -0.26, 'y': 0.21, 'z': 55.75}}},
#  60: {'ball': {'sleeping': False,
#    'location': {'x': -2769.83, 'y': -4451.13, 'z': 1041.74},
#    'rotation': {'x': 0.20610626,
#     'y': 0.3783304,
#     'z': 0.32204095,
#     'w': 0.84301597},
#    'linear_velocity': {'x': 1440.98, 'y': -316.78, 'z': -261.69},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  61: {'ball': {'sleeping': False,
#    'location': {'x': -2805.86, 'y': -4443.21, 'z': 1048.15},
#    'rotation': {'x': 0.13459799,
#     'y': 0.36666688,
#     'z': 0.33478346,
#     'w': 0.85753065},
#    'linear_velocity': {'x': 1442.09, 'y': -317.02, 'z': -245.64},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -3127.31, 'y': -1701.46, 'z': 17.01},
#    'rotation': {'x': 0.0019124553,
#     'y': 0.0043994565,
#     'z': -0.37911806,
#     'w': 0.9253359},
#    'linear_velocity': {'x': 1200.87, 'y': -1245.63, 'z': 0.04},
#    'angular_velocity': {'x': -0.01, 'y': 0.0, 'z': 156.95}}},
#  62: {'ball': {'sleeping': False,
#    'location': {'x': -2853.95, 'y': -4432.65, 'z': 1056.07},
#    'rotation': {'x': 0.038149472,
#     'y': 0.34792528,
#     'z': 0.348837,
#     'w': 0.8693707},
#    'linear_velocity': {'x': 1443.57, 'y': -317.34, 'z': -224.23},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  63: {'ball': {'sleeping': False,
#    'location': {'x': -2902.09, 'y': -4422.06, 'z': 1063.27},
#    'rotation': {'x': -0.05868211, 'y': 0.3257094, 'z': 0.3594, 'w': 0.8725259},
#    'linear_velocity': {'x': 1445.05, 'y': -317.66, 'z': -202.79},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  64: {'ball': {'sleeping': False,
#    'location': {'x': -2938.23, 'y': -4414.11, 'z': 1068.21},
#    'rotation': {'x': -0.13097268,
#     'y': 0.30689228,
#     'z': 0.3649675,
#     'w': 0.86917317},
#    'linear_velocity': {'x': 1446.16, 'y': -317.9, 'z': -186.7},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -3230.58, 'y': -1585.7, 'z': 17.01},
#    'rotation': {'x': 0.0020473253,
#     'y': 0.0043455088,
#     'z': -0.42586413,
#     'w': 0.90477437},
#    'linear_velocity': {'x': 1052.75, 'y': -1265.92, 'z': 0.06},
#    'angular_velocity': {'x': 0.16, 'y': -0.23, 'z': 34.92}}},
#  65: {'ball': {'sleeping': False,
#    'location': {'x': -2986.45, 'y': -4403.51, 'z': 1074.17},
#    'rotation': {'x': -0.22614262,
#     'y': 0.27914676,
#     'z': 0.36920244,
#     'w': 0.85710335},
#    'linear_velocity': {'x': 1447.64, 'y': -318.22, 'z': -165.22},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  66: {'car': {'sleeping': False,
#    'location': {'x': -3316.13, 'y': -1481.5, 'z': 17.01},
#    'rotation': {'x': 0.002031141,
#     'y': 0.004361693,
#     'z': -0.42825407,
#     'w': 0.9036456},
#    'linear_velocity': {'x': 1017.41, 'y': -1242.26, 'z': 0.26},
#    'angular_velocity': {'x': 0.02, 'y': -0.07, 'z': -0.99}}},
#  67: {'ball': {'sleeping': False,
#    'location': {'x': -3070.96, 'y': -4384.95, 'z': 1082.87},
#    'rotation': {'x': -0.3866978,
#     'y': 0.22406022,
#     'z': 0.36773503,
#     'w': 0.81549543},
#    'linear_velocity': {'x': 1450.23, 'y': -318.78, 'z': -127.59},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  68: {'ball': {'sleeping': False,
#    'location': {'x': -3119.32, 'y': -4374.31, 'z': 1086.85},
#    'rotation': {'x': -0.47344106,
#     'y': 0.18939318,
#     'z': 0.36183304,
#     'w': 0.7804234},
#    'linear_velocity': {'x': 1451.71, 'y': -319.1, 'z': -106.06},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -3392.45, 'y': -1388.35, 'z': 17.01},
#    'rotation': {'x': 0.002025746,
#     'y': 0.004361693,
#     'z': -0.42753652,
#     'w': 0.90398526},
#    'linear_velocity': {'x': 1017.97, 'y': -1241.85, 'z': 0.26},
#    'angular_velocity': {'x': 0.01, 'y': -0.06, 'z': -3.93}}},
#  69: {'ball': {'sleeping': False,
#    'location': {'x': -3204.07, 'y': -4355.69, 'z': 1092.08},
#    'rotation': {'x': -0.61337185,
#     'y': 0.12438563,
#     'z': 0.34286493,
#     'w': 0.7005333},
#    'linear_velocity': {'x': 1454.3, 'y': -319.73, 'z': -68.32},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  70: {'ball': {'sleeping': False,
#    'location': {'x': -3228.31, 'y': -4350.36, 'z': 1093.17},
#    'rotation': {'x': -0.65008354,
#     'y': 0.10502362,
#     'z': 0.33549017,
#     'w': 0.6736526},
#    'linear_velocity': {'x': 1455.04, 'y': -319.91, 'z': -57.52},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  71: {'ball': {'sleeping': False,
#    'location': {'x': -3276.83, 'y': -4339.68, 'z': 1094.81},
#    'rotation': {'x': 0.7185396,
#     'y': -0.065565914,
#     'z': -0.31823757,
#     'w': -0.61492014},
#    'linear_velocity': {'x': 1456.52, 'y': -320.27, 'z': -35.92},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -3468.73, 'y': -1295.16, 'z': 17.01},
#    'rotation': {'x': 0.0020149564,
#     'y': 0.004367088,
#     'z': -0.4265223,
#     'w': 0.90446424},
#    'linear_velocity': {'x': 1014.48, 'y': -1244.8, 'z': 0.26},
#    'angular_velocity': {'x': 0.03, 'y': -0.07, 'z': -0.38}}},
#  72: {'ball': {'sleeping': False,
#    'location': {'x': -3325.4, 'y': -4329.0, 'z': 1095.73},
#    'rotation': {'x': 0.77981824,
#     'y': -0.025455432,
#     'z': -0.2978074,
#     'w': -0.5500421},
#    'linear_velocity': {'x': 1458.0, 'y': -320.63, 'z': -14.29},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  73: {'ball': {'sleeping': False,
#    'location': {'x': -3386.18, 'y': -4315.65, 'z': 1095.87},
#    'rotation': {'x': 0.84539443,
#     'y': 0.024996875,
#     'z': -0.2681197,
#     'w': -0.46129733},
#    'linear_velocity': {'x': 1459.85, 'y': -321.08, 'z': 12.78},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  74: {'ball': {'sleeping': False,
#    'location': {'x': -3410.52, 'y': -4310.29, 'z': 1095.61},
#    'rotation': {'x': 0.8679839,
#     'y': 0.045108758,
#     'z': -0.25504267,
#     'w': -0.42370084},
#    'linear_velocity': {'x': 1460.59, 'y': -321.26, 'z': 23.64},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -3560.84, 'y': -1180.34, 'z': 17.01},
#    'rotation': {'x': 0.0019879825,
#     'y': 0.004367088,
#     'z': -0.42919278,
#     'w': 0.9032002},
#    'linear_velocity': {'x': 985.71, 'y': -1268.43, 'z': 0.26},
#    'angular_velocity': {'x': 0.05, 'y': -0.07, 'z': 18.44}}},
#  75: {'ball': {'sleeping': False,
#    'location': {'x': -3495.78, 'y': -4291.53, 'z': 1093.28},
#    'rotation': {'x': 0.9296399,
#     'y': 0.11430807,
#     'z': -0.20448247,
#     'w': -0.28441206},
#    'linear_velocity': {'x': 1463.22, 'y': -321.89, 'z': 61.66},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  76: {'ball': {'sleeping': False,
#    'location': {'x': -3520.17, 'y': -4286.17, 'z': 1092.21},
#    'rotation': {'x': 0.9421008,
#     'y': 0.13352442,
#     'z': -0.18881589,
#     'w': -0.24282882},
#    'linear_velocity': {'x': 1463.98, 'y': -322.07, 'z': 72.54},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}},
#   'car': {'sleeping': False,
#    'location': {'x': -3632.73, 'y': -1083.57, 'z': 17.01},
#    'rotation': {'x': 0.002031141,
#     'y': 0.0043509034,
#     'z': -0.4408294,
#     'w': 0.89757806},
#    'linear_velocity': {'x': 913.68, 'y': -1325.56, 'z': 0.26},
#    'angular_velocity': {'x': -0.08, 'y': 0.09, 'z': 64.12}}},
#  77: {'ball': {'sleeping': False,
#    'location': {'x': -3568.99, 'y': -4275.42, 'z': 1089.52},
#    'rotation': {'x': 0.9599329,
#     'y': 0.17091592,
#     'z': -0.1561125,
#     'w': -0.15794136},
#    'linear_velocity': {'x': 1465.5, 'y': -322.43, 'z': 94.3},
#    'angular_velocity': {'x': 437.98, 'y': 328.11, 'z': -245.98}}},
#  78: {'ball': {'sleeping': False,
#    'location': {'x': -3582.46, 'y': -4270.03, 'z': 1068.38},
#    'rotation': {'x': 0.954888,
#     'y': 0.17697428,
#     'z': -0.22636381,
#     'w': -0.07502303},
#    'linear_velocity': {'x': 204.3, 'y': -118.15, 'z': 565.24},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3697.14, 'y': -981.12, 'z': 17.01},
#    'rotation': {'x': 0.002295486,
#     'y': 0.004210639,
#     'z': -0.47886288,
#     'w': 0.87787664},
#    'linear_velocity': {'x': 778.75, 'y': -1421.5, 'z': 0.28},
#    'angular_velocity': {'x': -0.05, 'y': 0.09, 'z': 188.75}}},
#  79: {'ball': {'sleeping': False,
#    'location': {'x': -3589.26, 'y': -4266.09, 'z': 1049.26},
#    'rotation': {'x': 0.9372393,
#     'y': 0.17183304,
#     'z': -0.3030997,
#     'w': -0.013656969},
#    'linear_velocity': {'x': 204.54, 'y': -118.27, 'z': 587.52},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  80: {'ball': {'sleeping': False,
#    'location': {'x': -3596.09, 'y': -4262.13, 'z': 1029.39},
#    'rotation': {'x': 0.91022676,
#     'y': 0.16497616,
#     'z': -0.3768037,
#     'w': 0.047843922},
#    'linear_velocity': {'x': 204.78, 'y': -118.39, 'z': 609.81},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3753.49, 'y': -857.5, 'z': 17.01},
#    'rotation': {'x': 0.0026299632,
#     'y': 0.0039948467,
#     'z': -0.5501122,
#     'w': 0.83507705},
#    'linear_velocity': {'x': 542.93, 'y': -1555.07, 'z': 0.28},
#    'angular_velocity': {'x': 0.02, 'y': 0.0, 'z': 200.98}}},
#  81: {'ball': {'sleeping': False,
#    'location': {'x': -3604.64, 'y': -4257.18, 'z': 1003.52},
#    'rotation': {'x': 0.8637124,
#     'y': 0.15409486,
#     'z': -0.46355775,
#     'w': 0.12397563},
#    'linear_velocity': {'x': 205.08, 'y': -118.54, 'z': 637.71},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  82: {'ball': {'sleeping': False,
#    'location': {'x': -3608.06, 'y': -4255.2, 'z': 992.85},
#    'rotation': {'x': 0.8412871,
#     'y': 0.14905612,
#     'z': -0.4963043,
#     'w': 0.1539492},
#    'linear_velocity': {'x': 205.2, 'y': -118.6, 'z': 648.88},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  83: {'ball': {'sleeping': False,
#    'location': {'x': -3618.32, 'y': -4249.26, 'z': 959.71},
#    'rotation': {'x': 0.7616436,
#     'y': 0.13176571,
#     'z': -0.58678615,
#     'w': 0.2412859},
#    'linear_velocity': {'x': 205.56, 'y': -118.78, 'z': 682.42},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3791.37, 'y': -710.26, 'z': 17.01},
#    'rotation': {'x': 0.00298602,
#     'y': 0.0037466863,
#     'z': -0.62442577,
#     'w': 0.78106946},
#    'linear_velocity': {'x': 253.85, 'y': -1658.12, 'z': 0.28},
#    'angular_velocity': {'x': 0.0, 'y': 0.0, 'z': 200.02}}},
#  84: {'ball': {'sleeping': False,
#    'location': {'x': -3623.45, 'y': -4246.29, 'z': 942.51},
#    'rotation': {'x': 0.71528065,
#     'y': 0.12197955,
#     'z': -0.6272041,
#     'w': 0.2830364},
#    'linear_velocity': {'x': 205.74, 'y': -118.87, 'z': 699.22},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  85: {'ball': {'sleeping': False,
#    'location': {'x': -3630.32, 'y': -4242.33, 'z': 918.92},
#    'rotation': {'x': -0.6472567,
#     'y': -0.107882865,
#     'z': 0.67557037,
#     'w': -0.3361915},
#    'linear_velocity': {'x': 205.98, 'y': -118.99, 'z': 721.62},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  86: {'ball': {'sleeping': False,
#    'location': {'x': -3637.2, 'y': -4238.37, 'z': 894.59},
#    'rotation': {'x': -0.5727596,
#     'y': -0.09270182,
#     'z': 0.7171944,
#     'w': -0.38598567},
#    'linear_velocity': {'x': 206.22, 'y': -119.11, 'z': 744.06},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3802.01, 'y': -555.88, 'z': 17.01},
#    'rotation': {'x': 0.0033258921,
#     'y': 0.0034499725,
#     'z': -0.6933716,
#     'w': 0.72056425},
#    'linear_velocity': {'x': -51.31, 'y': -1690.15, 'z': 0.06},
#    'angular_velocity': {'x': 0.0, 'y': 0.0, 'z': 201.16}}},
#  87: {'ball': {'sleeping': False,
#    'location': {'x': -3642.36, 'y': -4235.4, 'z': 875.85},
#    'rotation': {'x': -0.51309294,
#     'y': -0.08070375,
#     'z': 0.74372613,
#     'w': -0.4208254},
#    'linear_velocity': {'x': 206.4, 'y': -119.2, 'z': 760.89},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  88: {'ball': {'sleeping': False,
#    'location': {'x': -3649.24, 'y': -4231.44, 'z': 850.21},
#    'rotation': {'x': -0.42910105,
#     'y': -0.06400681,
#     'z': 0.77257985,
#     'w': -0.46356854},
#    'linear_velocity': {'x': 206.64, 'y': -119.32, 'z': 783.37},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3789.91, 'y': -431.44, 'z': 17.01},
#    'rotation': {'x': -0.003568658,
#     'y': -0.003196417,
#     'z': 0.74591863,
#     'w': -0.66601986},
#    'linear_velocity': {'x': -295.74, 'y': -1613.84, 'z': 0.06},
#    'angular_velocity': {'x': 0.01, 'y': 0.0, 'z': 203.08}}},
#  89: {'ball': {'sleeping': False,
#    'location': {'x': -3656.12, 'y': -4227.47, 'z': 823.82},
#    'rotation': {'x': -0.34083107,
#     'y': -0.04667325,
#     'z': 0.7937031,
#     'w': -0.50168836},
#    'linear_velocity': {'x': 206.88, 'y': -119.44, 'z': 805.86},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  90: {'ball': {'sleeping': False,
#    'location': {'x': -3661.28, 'y': -4224.47, 'z': 803.53},
#    'rotation': {'x': -0.27233848,
#     'y': -0.03335885,
#     'z': 0.80435634,
#     'w': -0.5270008},
#    'linear_velocity': {'x': 207.06, 'y': -119.53, 'z': 822.75},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3760.1, 'y': -313.9, 'z': 17.01},
#    'rotation': {'x': -0.0038114237,
#     'y': -0.002905098,
#     'z': 0.79460454,
#     'w': -0.6071084},
#    'linear_velocity': {'x': -520.64, 'y': -1502.57, 'z': 0.06},
#    'angular_velocity': {'x': 0.0, 'y': 0.0, 'z': 204.79}}},
#  91: {'ball': {'sleeping': False,
#    'location': {'x': -3675.12, 'y': -4216.47, 'z': 747.36},
#    'rotation': {'x': -0.0832879,
#     'y': 0.0028565447,
#     'z': 0.8105745,
#     'w': -0.5796758},
#    'linear_velocity': {'x': 207.54, 'y': -119.77, 'z': 867.84},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3714.2, 'y': -205.78, 'z': 17.01},
#    'rotation': {'x': -0.004016426,
#     'y': -0.002613779,
#     'z': 0.83901566,
#     'w': -0.54408616},
#    'linear_velocity': {'x': -721.17, 'y': -1360.14, 'z': 0.06},
#    'angular_velocity': {'x': 0.0, 'y': 0.0, 'z': 206.93}}},
#  92: {'ball': {'sleeping': False,
#    'location': {'x': -3680.31, 'y': -4213.47, 'z': 725.52},
#    'rotation': {'x': -0.0111214155,
#     'y': 0.016483884,
#     'z': 0.80454254,
#     'w': -0.59356207},
#    'linear_velocity': {'x': 207.72, 'y': -119.86, 'z': 884.77},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  93: {'ball': {'sleeping': False,
#    'location': {'x': -3683.77, 'y': -4211.47, 'z': 710.73},
#    'rotation': {'x': 0.037048932,
#     'y': 0.025525564,
#     'z': 0.798005,
#     'w': -0.60096914},
#    'linear_velocity': {'x': 207.84, 'y': -119.92, 'z': 896.07},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3714.2, 'y': -205.78, 'z': 17.01},
#    'rotation': {'x': -0.004016426,
#     'y': -0.002613779,
#     'z': 0.83901566,
#     'w': -0.54408616},
#    'linear_velocity': {'x': -721.17, 'y': -1360.14, 'z': 0.06},
#    'angular_velocity': {'x': 0.0, 'y': 0.0, 'z': 206.93}}},
#  94: {'ball': {'sleeping': False,
#    'location': {'x': -3694.15, 'y': -4205.47, 'z': 665.22},
#    'rotation': {'x': 0.18051326,
#     'y': 0.052175943,
#     'z': 0.7665249,
#     'w': -0.61411095},
#    'linear_velocity': {'x': 208.2, 'y': -120.1, 'z': 929.99},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  95: {'ball': {'sleeping': False,
#    'location': {'x': -3699.37, 'y': -4202.47, 'z': 641.83},
#    'rotation': {'x': 0.2509264,
#     'y': 0.06510196,
#     'z': 0.74426746,
#     'w': -0.615519},
#    'linear_velocity': {'x': 208.38, 'y': -120.19, 'z': 946.97},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  96: {'ball': {'sleeping': False,
#    'location': {'x': -3702.85, 'y': -4200.47, 'z': 626.0},
#    'rotation': {'x': 0.29710603,
#     'y': 0.073517844,
#     'z': 0.72709966,
#     'w': -0.6145317},
#    'linear_velocity': {'x': 208.5, 'y': -120.25, 'z': 958.29},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3639.15, 'y': -89.58, 'z': 17.01},
#    'rotation': {'x': -0.0042537972,
#     'y': -0.0022037744,
#     'z': 0.88726074,
#     'w': -0.4612434},
#    'linear_velocity': {'x': -926.96, 'y': -1150.19, 'z': 0.06},
#    'angular_velocity': {'x': 0.01, 'y': 0.01, 'z': 212.58}}},
#  97: {'ball': {'sleeping': False,
#    'location': {'x': -3713.29, 'y': -4194.47, 'z': 577.38},
#    'rotation': {'x': 0.43074644,
#     'y': 0.09757872,
#     'z': 0.66487455,
#     'w': -0.6023933},
#    'linear_velocity': {'x': 208.86, 'y': -120.43, 'z': 992.31},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3582.35, 'y': -26.19, 'z': 17.01},
#    'rotation': {'x': -0.004388667,
#     'y': -0.0019340345,
#     'z': 0.91429347,
#     'w': -0.40502396},
#    'linear_velocity': {'x': -1031.91, 'y': -1000.53, 'z': 0.07},
#    'angular_velocity': {'x': 0.03, 'y': 0.01, 'z': 215.31}}},
#  98: {'ball': {'sleeping': False,
#    'location': {'x': -3718.51, 'y': -4191.47, 'z': 552.43},
#    'rotation': {'x': 0.49411935,
#     'y': 0.108821556,
#     'z': 0.62805706,
#     'w': -0.5912261},
#    'linear_velocity': {'x': 209.04, 'y': -120.52, 'z': 1009.34},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3565.04, 'y': -9.7, 'z': 17.01},
#    'rotation': {'x': -0.0044210358,
#     'y': -0.0018477178,
#     'z': 0.921416,
#     'w': -0.3885482},
#    'linear_velocity': {'x': -1057.68, 'y': -956.17, 'z': 0.09},
#    'angular_velocity': {'x': 0.04, 'y': 0.01, 'z': 215.67}}},
#  99: {'ball': {'sleeping': False,
#    'location': {'x': -3728.95, 'y': -4185.46, 'z': 501.25},
#    'rotation': {'x': 0.61218405,
#     'y': 0.12940818,
#     'z': 0.54407,
#     'w': -0.558992},
#    'linear_velocity': {'x': 209.4, 'y': -120.7, 'z': 1043.43},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  100: {'ball': {'sleeping': False,
#    'location': {'x': -3732.45, 'y': -4183.44, 'z': 483.81},
#    'rotation': {'x': 0.64860505,
#     'y': 0.13564457,
#     'z': 0.51325476,
#     'w': -0.5454187},
#    'linear_velocity': {'x': 209.52, 'y': -120.76, 'z': 1054.81},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3491.87, 'y': 48.82, 'z': 17.01},
#    'rotation': {'x': -0.004550511,
#     'y': -0.0015024508,
#     'z': 0.94685847,
#     'w': -0.3216147},
#    'linear_velocity': {'x': -1155.23, 'y': -785.57, 'z': 0.29},
#    'angular_velocity': {'x': 0.06, 'y': 0.05, 'z': 212.04}}},
#  101: {'ball': {'sleeping': False,
#    'location': {'x': -3741.2, 'y': -4178.39, 'z': 439.39},
#    'rotation': {'x': 0.73238474,
#     'y': 0.14972508,
#     'z': 0.4307842,
#     'w': -0.50558877},
#    'linear_velocity': {'x': 209.82, 'y': -120.91, 'z': 1083.27},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  102: {'ball': {'sleeping': False,
#    'location': {'x': -3748.2, 'y': -4174.35, 'z': 403.0},
#    'rotation': {'x': 0.7912369,
#     'y': 0.15931702,
#     'z': 0.3598963,
#     'w': -0.46801385},
#    'linear_velocity': {'x': 210.06, 'y': -121.03, 'z': 1106.07},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  103: {'ball': {'sleeping': False,
#    'location': {'x': -3756.95, 'y': -4169.3, 'z': 356.44},
#    'rotation': {'x': 0.8536223,
#     'y': 0.16905472,
#     'z': 0.26632324,
#     'w': -0.4145135},
#    'linear_velocity': {'x': 210.36, 'y': -121.18, 'z': 1134.6},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
#    'location': {'x': -3369.59, 'y': 117.2, 'z': 17.01},
#    'rotation': {'x': -0.0046961703,
#     'y': -0.0009845503,
#     'z': 0.9747245,
#     'w': -0.2233589},
#    'linear_velocity': {'x': -1292.37, 'y': -568.26, 'z': 0.29},
#    'angular_velocity': {'x': 0.08, 'y': 0.04, 'z': 190.51}}},
#  104: {'ball': {'sleeping': False,
#    'location': {'x': -3760.45, 'y': -4167.28, 'z': 337.48},
#    'rotation': {'x': 0.8748923,
#     'y': 0.17221607,
#     'z': 0.22764777,
#     'w': -0.39125645},
#    'linear_velocity': {'x': 210.48, 'y': -121.24, 'z': 1146.02},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}}},
#  105: {'ball': {'sleeping': False,
#    'location': {'x': -3767.47, 'y': -4163.24, 'z': 298.99},
#    'rotation': {'x': 0.9108255,
#     'y': 0.17724402,
#     'z': 0.14868927,
#     'w': -0.34186685},
#    'linear_velocity': {'x': 210.72, 'y': -121.36, 'z': 1168.88},
#    'angular_velocity': {'x': 432.83, 'y': -401.41, 'z': -107.35}},
#   'car': {'sleeping': False,
# ...
#    'location': {'x': -2567.57, 'y': 334.0, 'z': 17.01},
#    'rotation': {'x': -0.004760908,
#     'y': -0.00037493836,
#     'z': 0.995817,
#     'w': -0.09124523},
#    'linear_velocity': {'x': -1408.63, 'y': -245.27, 'z': 0.26},
#    'angular_velocity': {'x': 0.0, 'y': -0.05, 'z': 95.04}}},
#  121: {'ball': {'sleeping': False,
#    'location': {'x': -3169.3, 'y': -3295.85, 'z': 212.21},
#    'rotation': {'x': 0.8541407,
#     'y': 0.17531808,
#     'z': -0.38091993,
#     'w': -0.3075828},
#    'linear_velocity': {'x': -1509.44, 'y': -2083.22, 'z': -239.74},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  122: {'ball': {'sleeping': False,
#    'location': {'x': -3118.96, 'y': -3226.39, 'z': 219.93},
#    'rotation': {'x': 0.840683,
#     'y': 0.17979576,
#     'z': -0.37903175,
#     'w': -0.3424333},
#    'linear_velocity': {'x': -1511.0, 'y': -2085.34, 'z': -218.32},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  123: {'ball': {'sleeping': False,
#    'location': {'x': -3081.17, 'y': -3174.24, 'z': 225.25},
#    'rotation': {'x': 0.8298071,
#     'y': 0.18298408,
#     'z': -0.37726226,
#     'w': -0.36825293},
#    'linear_velocity': {'x': -1512.17, 'y': -2086.93, 'z': -202.24},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -2461.48, 'y': 350.3, 'z': 17.01},
#    'rotation': {'x': -0.004760908,
#     'y': -0.00030480602,
#     'z': 0.9978886,
#     'w': -0.064772874},
#    'linear_velocity': {'x': -1420.4, 'y': -185.73, 'z': 0.25},
#    'angular_velocity': {'x': -0.09, 'y': -0.07, 'z': 20.55}}},
#  124: {},
#  125: {'ball': {'sleeping': False,
#    'location': {'x': -2967.65, 'y': -3017.56, 'z': 238.82},
#    'rotation': {'x': 0.7932436,
#     'y': 0.19167519,
#     'z': -0.3701519,
#     'w': -0.44386128},
#    'linear_velocity': {'x': -1515.68, 'y': -2091.7, 'z': -153.93},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -2331.17, 'y': 366.61, 'z': 17.01},
#    'rotation': {'x': -0.004760908,
#     'y': -0.00030480602,
#     'z': 0.9980701,
#     'w': -0.061913636},
#    'linear_velocity': {'x': -1422.23, 'y': -172.8, 'z': 0.19},
#    'angular_velocity': {'x': 0.0, 'y': -0.05, 'z': 2.7}}},
#  126: {'ball': {'sleeping': False,
#    'location': {'x': -2917.11, 'y': -2947.81, 'z': 243.68},
#    'rotation': {'x': 0.7751432,
#     'y': 0.19510087,
#     'z': -0.36613813,
#     'w': -0.47647834},
#    'linear_velocity': {'x': -1517.24, 'y': -2093.85, 'z': -132.42},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  127: {'ball': {'sleeping': False,
#    'location': {'x': -2866.52, 'y': -2877.99, 'z': 247.82},
#    'rotation': {'x': 0.75594354,
#     'y': 0.19825144,
#     'z': -0.36160648,
#     'w': -0.50841564},
#    'linear_velocity': {'x': -1518.8, 'y': -2096.01, 'z': -110.9},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -2248.61, 'y': 376.47, 'z': 17.01},
#    'rotation': {'x': -0.004760908,
#     'y': -0.00030480602,
#     'z': 0.9981489,
#     'w': -0.060629632},
#    'linear_velocity': {'x': -1388.68, 'y': -161.13, 'z': 0.03},
#    'angular_velocity': {'x': 0.0, 'y': -0.03, 'z': 7.77}}},
#  128: {'ball': {'sleeping': False,
#    'location': {'x': -2828.54, 'y': -2825.57, 'z': 250.45},
#    'rotation': {'x': 0.74084204,
#     'y': 0.20043093,
#     'z': -0.35786787,
#     'w': -0.5318939},
#    'linear_velocity': {'x': -1519.97, 'y': -2097.63, 'z': -94.73},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -2225.55, 'y': 379.13, 'z': 17.01},
#    'rotation': {'x': -0.004760908,
#     'y': -0.00030480602,
#     'z': 0.9981913,
#     'w': -0.05992831},
#    'linear_velocity': {'x': -1369.7, 'y': -155.86, 'z': 0.03},
#    'angular_velocity': {'x': 0.01, 'y': -0.03, 'z': 10.67}}},
#  129: {'ball': {'sleeping': False,
#    'location': {'x': -2752.49, 'y': -2720.63, 'z': 254.5},
#    'rotation': {'x': 0.7088704,
#     'y': 0.2043044,
#     'z': -0.3495329,
#     'w': -0.5775718},
#    'linear_velocity': {'x': -1522.31, 'y': -2100.87, 'z': -62.37},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  130: {'ball': {'sleeping': False,
#    'location': {'x': -2714.42, 'y': -2668.09, 'z': 255.92},
#    'rotation': {'x': 0.6920274,
#     'y': 0.20599836,
#     'z': -0.34494728,
#     'w': -0.59972835},
#    'linear_velocity': {'x': -1523.48, 'y': -2102.49, 'z': -46.17},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -2125.77, 'y': 389.97, 'z': 17.01},
#    'rotation': {'x': -0.004760908,
#     'y': -0.00026164763,
#     'z': 0.9985985,
#     'w': -0.05271007},
#    'linear_velocity': {'x': -1280.4, 'y': -128.1, 'z': 0.03},
#    'angular_velocity': {'x': -0.02, 'y': -0.03, 'z': 26.03}}},
#  131: {'ball': {'sleeping': False,
#    'location': {'x': -2663.61, 'y': -2597.98, 'z': 257.18},
#    'rotation': {'x': 0.6687212,
#     'y': 0.20799984,
#     'z': -0.3384034,
#     'w': -0.62851506},
#    'linear_velocity': {'x': -1525.04, 'y': -2104.65, 'z': -24.55},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  132: {'ball': {'sleeping': False,
#    'location': {'x': -2612.75, 'y': -2527.8, 'z': 257.72},
#    'rotation': {'x': -0.64446217,
#     'y': -0.20970464,
#     'z': 0.33137932,
#     'w': 0.6564147},
#    'linear_velocity': {'x': -1526.6, 'y': -2106.81, 'z': -2.91},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -2023.04, 'y': 399.25, 'z': 17.01},
#    'rotation': {'x': -0.004760908,
#     'y': -0.00023467364,
#     'z': 0.9990921,
#     'w': -0.042335834},
#    'linear_velocity': {'x': -1172.79, 'y': -91.22, 'z': 0.03},
#    'angular_velocity': {'x': -0.12, 'y': -0.02, 'z': 22.56}}},
#  133: {'ball': {'sleeping': False,
#    'location': {'x': -2549.12, 'y': -2439.97, 'z': 257.38},
#    'rotation': {'x': -0.6128593,
#     'y': -0.21142018,
#     'z': 0.32193846,
#     'w': 0.68997145},
#    'linear_velocity': {'x': -1528.55, 'y': -2109.51, 'z': 24.2},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  134: {'ball': {'sleeping': False,
#    'location': {'x': -2523.64, 'y': -2404.81, 'z': 256.93},
#    'rotation': {'x': -0.59983623,
#     'y': -0.21197584,
#     'z': 0.3179624,
#     'w': 0.70296705},
#    'linear_velocity': {'x': -1529.33, 'y': -2110.59, 'z': 35.06},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  135: {'ball': {'sleeping': False,
#    'location': {'x': -2434.37, 'y': -2281.59, 'z': 253.94},
#    'rotation': {'x': -0.5525938,
#     'y': -0.21332455,
#     'z': 0.30316448,
#     'w': 0.7464744},
#    'linear_velocity': {'x': -1532.06, 'y': -2114.37, 'z': 73.11},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -1912.16, 'y': 406.01, 'z': 17.01},
#    'rotation': {'x': -0.004760908,
#     'y': -0.00025625282,
#     'z': 0.9994933,
#     'w': -0.03147067},
#    'linear_velocity': {'x': -1030.55, 'y': -34.97, 'z': 0.03},
#    'angular_velocity': {'x': -0.08, 'y': 0.0, 'z': 30.97}}},
#  136: {'ball': {'sleeping': False,
#    'location': {'x': -2383.28, 'y': -2211.09, 'z': 251.23},
#    'rotation': {'x': -0.5245084,
#     'y': -0.2136806,
#     'z': 0.2941119,
#     'w': 0.7698894},
#    'linear_velocity': {'x': -1533.62, 'y': -2116.53, 'z': 94.87},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  137: {'ball': {'sleeping': False,
#    'location': {'x': -2357.72, 'y': -2175.81, 'z': 249.6},
#    'rotation': {'x': -0.5101851,
#     'y': -0.21374534,
#     'z': 0.28942922,
#     'w': 0.7811881},
#    'linear_velocity': {'x': -1534.4, 'y': -2117.61, 'z': 105.77},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  138: {'ball': {'sleeping': False,
#    'location': {'x': -2319.35, 'y': -2122.85, 'z': 246.82},
#    'rotation': {'x': -0.48835772,
#     'y': -0.21370217,
#     'z': 0.282211,
#     'w': 0.7976184},
#    'linear_velocity': {'x': -1535.57, 'y': -2119.23, 'z': 122.12},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -1838.63, 'y': 406.55, 'z': 17.01},
#    'rotation': {'x': -0.004760908,
#     'y': -0.0001429621,
#     'z': 0.9999456,
#     'w': -0.00928179},
#    'linear_velocity': {'x': -930.2, 'y': 33.31, 'z': 0.26},
#    'angular_velocity': {'x': 0.18, 'y': 0.0, 'z': 109.29}}},
#  139: {'ball': {'sleeping': False,
#    'location': {'x': -2242.52, 'y': -2016.83, 'z': 240.03},
#    'rotation': {'x': -0.44355378,
#     'y': -0.21310335,
#     'z': 0.26711088,
#     'w': 0.8285522},
#    'linear_velocity': {'x': -1537.91, 'y': -2122.47, 'z': 154.86},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  140: {'ball': {'sleeping': False,
#    'location': {'x': -2165.57, 'y': -1910.63, 'z': 231.6},
#    'rotation': {'x': -0.39733636,
#     'y': -0.21182479,
#     'z': 0.251153,
#     'w': 0.85684085},
#    'linear_velocity': {'x': -1540.25, 'y': -2125.71, 'z': 187.65},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -1748.82, 'y': 397.28, 'z': 17.01},
#    'rotation': {'x': -0.0047393288,
#     'y': 0.00040191234,
#     'z': 0.9964362,
#     'w': 0.084215805},
#    'linear_velocity': {'x': -855.33, 'y': 179.14, 'z': 0.29},
#    'angular_velocity': {'x': 0.0, 'y': -0.01, 'z': 249.82}}},
#  141: {'ball': {'sleeping': False,
#    'location': {'x': -2152.73, 'y': -1892.92, 'z': 230.04},
#    'rotation': {'x': -0.38950852,
#     'y': -0.21154426,
#     'z': 0.24841243,
#     'w': 0.8612917},
#    'linear_velocity': {'x': -1540.65, 'y': -2126.25, 'z': 193.12},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  142: {'ball': {'sleeping': False,
#    'location': {'x': -2075.64, 'y': -1786.54, 'z': 219.7},
#    'rotation': {'x': -0.3418291,
#     'y': -0.20947266,
#     'z': 0.23151584,
#     'w': 0.8863828},
#    'linear_velocity': {'x': -1543.05, 'y': -2129.49, 'z': 225.97},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  143: {'ball': {'sleeping': False,
#    'location': {'x': -2049.92, 'y': -1751.04, 'z': 215.89},
#    'rotation': {'x': -0.3256824,
#     'y': -0.20863107,
#     'z': 0.22572182,
#     'w': 0.8941217},
#    'linear_velocity': {'x': -1543.85, 'y': -2130.57, 'z': 236.93},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -1674.37, 'y': 373.71, 'z': 17.01},
#    'rotation': {'x': -0.0046584066,
#     'y': 0.0009359972,
#     'z': 0.980253,
#     'w': 0.19769038},
#    'linear_velocity': {'x': -753.26, 'y': 344.39, 'z': 0.29},
#    'angular_velocity': {'x': 0.0, 'y': -0.01, 'z': 250.4}}},
#  144: {'ball': {'sleeping': False,
#    'location': {'x': -2011.31, 'y': -1697.77, 'z': 209.83},
#    'rotation': {'x': -0.30124927,
#     'y': -0.20723382,
#     'z': 0.21687976,
#     'w': 0.90513325},
#    'linear_velocity': {'x': -1545.05, 'y': -2132.21, 'z': 253.37},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  145: {'ball': {'sleeping': False,
#    'location': {'x': -1934.0, 'y': -1591.09, 'z': 196.48},
#    'rotation': {'x': -0.2516871,
#     'y': -0.20394295,
#     'z': 0.19867763,
#     'w': 0.92498004},
#    'linear_velocity': {'x': -1547.45, 'y': -2135.51, 'z': 286.31},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -1632.46, 'y': 351.42, 'z': 17.01},
#    'rotation': {'x': -0.0045828796,
#     'y': 0.0012758693,
#     'z': 0.9632281,
#     'w': 0.268643},
#    'linear_velocity': {'x': -670.46, 'y': 428.87, 'z': 0.29},
#    'angular_velocity': {'x': 0.0, 'y': -0.01, 'z': 249.85}}},
#  146: {'ball': {'sleeping': False,
#    'location': {'x': -1882.39, 'y': -1519.87, 'z': 186.66},
#    'rotation': {'x': -0.21818529,
#     'y': -0.20138042,
#     'z': 0.18619399,
#     'w': 0.9365751},
#    'linear_velocity': {'x': -1549.05, 'y': -2137.71, 'z': 308.3},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  147: {'ball': {'sleeping': False,
#    'location': {'x': -1843.65, 'y': -1466.42, 'z': 178.81},
#    'rotation': {'x': -0.1928566,
#     'y': -0.19927645,
#     'z': 0.17664519,
#     'w': 0.9444002},
#    'linear_velocity': {'x': -1550.25, 'y': -2139.36, 'z': 324.8},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  148: {'ball': {'sleeping': False,
#    'location': {'x': -1791.95, 'y': -1395.08, 'z': 167.71},
#    'rotation': {'x': -0.15884228,
#     'y': -0.19622299,
#     'z': 0.16370839,
#     'w': 0.9536588},
#    'linear_velocity': {'x': -1551.85, 'y': -2141.56, 'z': 346.83},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -1577.06, 'y': 307.83, 'z': 17.01},
#    'rotation': {'x': -0.0044048512,
#     'y': 0.0018045595,
#     'z': 0.92641026,
#     'w': 0.3764854},
#    'linear_velocity': {'x': -522.39, 'y': 522.55, 'z': 0.29},
#    'angular_velocity': {'x': 0.0, 'y': -0.01, 'z': 246.92}}},
#  149: {'ball': {'sleeping': False,
#    'location': {'x': -1740.2, 'y': -1323.66, 'z': 155.87},
#    'rotation': {'x': -0.12460677,
#     'y': -0.19288898,
#     'z': 0.1505343,
#     'w': 0.9615646},
#    'linear_velocity': {'x': -1553.45, 'y': -2143.76, 'z': 368.87},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  150: {'ball': {'sleeping': False,
#    'location': {'x': -1701.35, 'y': -1270.06, 'z': 146.51},
#    'rotation': {'x': -0.09880877,
#     'y': -0.19020775,
#     'z': 0.14051068,
#     'w': 0.96659946},
#    'linear_velocity': {'x': -1554.65, 'y': -2145.41, 'z': 385.43},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -1549.06, 'y': 276.44, 'z': 17.01},
#    'rotation': {'x': -0.0042537972,
#     'y': 0.002106668,
#     'z': 0.8970981,
#     'w': 0.44180584},
#    'linear_velocity': {'x': -423.39, 'y': 555.15, 'z': 0.28},
#    'angular_velocity': {'x': 0.0, 'y': 0.0, 'z': 243.27}}},
#  151: {'ball': {'sleeping': False,
#    'location': {'x': -1649.5, 'y': -1198.52, 'z': 133.39},
#    'rotation': {'x': -0.06429814,
#     'y': -0.18639903,
#     'z': 0.12698053,
#     'w': 0.9721096},
#    'linear_velocity': {'x': -1556.25, 'y': -2147.61, 'z': 407.51},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  152: {'ball': {'sleeping': False,
#    'location': {'x': -1558.64, 'y': -1073.14, 'z': 108.65},
#    'rotation': {'x': -0.0037143175,
#     'y': -0.17911062,
#     'z': 0.1028711,
#     'w': 0.97842896},
#    'linear_velocity': {'x': -1559.05, 'y': -2151.46, 'z': 446.22},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}},
#   'car': {'sleeping': False,
#    'location': {'x': -1516.59, 'y': 224.82, 'z': 17.01},
#    'rotation': {'x': -0.0040002414,
#     'y': 0.0025652258,
#     'z': 0.84335756,
#     'w': 0.5373318},
#    'linear_velocity': {'x': -273.64, 'y': 563.11, 'z': 0.28},
#    'angular_velocity': {'x': -0.01, 'y': 0.0, 'z': 233.36}}},
#  153: {'ball': {'sleeping': False,
#    'location': {'x': -1532.65, 'y': -1037.28, 'z': 101.17},
#    'rotation': {'x': 0.013613854,
#     'y': -0.17688257,
#     'z': 0.09589554,
#     'w': 0.9794546},
#    'linear_velocity': {'x': -1559.85, 'y': -2152.56, 'z': 457.3},
#    'angular_velocity': {'x': -215.71, 'y': -49.47, 'z': 46.02}}},
#  154: {'ball': {'sleeping': False,
#    'location': {'x': -1484.35, 'y': -990.09, 'z': 93.15},
#    'rotation': {'x': -0.018134693,
#     'y': -0.08744729,
#     'z': 0.09487053,
#     'w': 0.9914755},
#    'linear_velocity': {'x': -655.79, 'y': -451.74, 'z': 0.0},
#    'angular_velocity': {'x': 341.07, 'y': -493.58, 'z': 6.21}}},
#  155: {'ball': {'sleeping': False,
#    'location': {'x': -1478.88, 'y': -986.33, 'z': 93.15},
#    'rotation': {'x': -0.030397108,
#     'y': -0.06549039,
#     'z': 0.09620844,
#     'w': 0.99273914},
#    'linear_velocity': {'x': -657.53, 'y': -452.93, 'z': 0.0},
#    'angular_velocity': {'x': 341.09, 'y': -493.57, 'z': 6.27}},
#   'car': {'sleeping': False,
#    'location': {'x': -1499.71, 'y': 183.41, 'z': 17.01},
#    'rotation': {'x': -0.0037574759,
#     'y': 0.0028889135,
#     'z': 0.79444,
#     'w': 0.6073242},
#    'linear_velocity': {'x': -168.88, 'y': 532.5, 'z': 0.28},
#    'angular_velocity': {'x': -0.04, 'y': 0.03, 'z': 219.58}}}}

# %%
output = []
for goal in goals:
    raw_data = build_dataset_goal(goal)
    interpolated_data = interpolate_missing_data(raw_data)
    shaved_data = {f: interpolated_data[f] for f in interpolated_data.keys() if not f % 5 and f <= 150}
    flattened_data = flatten_game_state(shaved_data)
    output.append(flattened_data)
output
# Out:
# [array([ 0.00000000e+00, -1.79089996e+02,  4.88075977e+03,  2.62119995e+02,
#          6.97472811e-01, -5.01666784e-01, -3.33181202e-01, -3.88397157e-01,
#          1.16567004e+03,  2.14079004e+03, -2.59799995e+01,  5.83099976e+02,
#          1.15570000e+02,  8.14000015e+01,  0.00000000e+00, -2.27830002e+02,
#          4.68808984e+03,  1.95445007e+02,  9.10907507e-01, -5.81642315e-02,
#         -1.59640729e-01, -3.59240860e-01,  1.19934497e+03,  1.96222498e+03,
#         -2.48750000e+01, -5.06950012e+02, -2.11919998e+02, -2.41550007e+01,
#          0.00000000e+00, -3.44559998e+02,  4.57687012e+03,  2.59660004e+02,
#          7.89462686e-01, -5.98714113e-01, -2.54014842e-02, -1.32833883e-01,
#          1.17077002e+03,  2.15013989e+03,  6.62300034e+01,  5.83099976e+02,
#          1.15570000e+02,  8.14000015e+01,  0.00000000e+00, -3.87850006e+02,
#          4.41450977e+03,  1.99110001e+02, -5.96906841e-01,  2.53259558e-02,
#          3.51350963e-01,  7.20842123e-01,  1.11966003e+03,  2.00285999e+03,
#         -2.67700005e+01, -5.07480011e+02, -2.09729996e+02, -3.11599998e+01,
#          0.00000000e+00, -5.26059998e+02,  4.30885986e+03,  2.72589996e+02,
#          7.73750603e-01, -4.96897727e-01,  3.72816950e-01,  1.24137469e-01,
#          1.03856995e+03,  1.28701001e+03, -1.40820007e+02,  5.32580017e+02,
#          2.42880005e+02, -1.31779999e+02,  0.00000000e+00,
+02, -2.27279999e+02,
#         -1.83440002e+02, -4.76489990e+02,  0.00000000e+00, -2.70044995e+03,
#         -4.22305664e+03,  1.59033337e+01, -3.02917836e-03,  5.40378795e-04,
#          9.99194562e-01,  2.57449523e-02, -1.62276672e+03, -1.07553337e+02,
#          1.21566668e+01,  1.40833330e+01, -2.63333344e+00, -1.59996674e+02,
#          0.00000000e+00, -1.46889999e+02, -6.07000017e+00,  1.69449997e+02,
#          1.83828529e-02, -1.03809752e-01, -4.12299000e-02,  9.93572176e-01,
#         -1.87352002e+03, -2.64890015e+02,  8.05679993e+02, -2.27279999e+02,
#         -1.83440002e+02, -4.76489990e+02,  0.00000000e+00, -2.40852002e+03,
#         -4.13600000e+03,  3.94799995e+01, -5.08434698e-02,  1.95575625e-01,
#          9.71438825e-01, -1.24385588e-01, -1.58981995e+03, -8.25229980e+02,
#         -2.56450012e+02,  7.66999969e+01,  8.49499969e+01, -1.07250000e+02,
#          0.00000000e+00,  1.07379997e+02, -3.45900002e+01,  2.69200001e+01,
#          7.15595186e-02,  6.01242995e-03, -4.12622802e-02,  1.00086057e+00,
#          8.65119995e+02, -2.95985010e+03,  1.71692004e+03, -1.53043994e+03,
#          3.69199982e+01,  2.20546997e+03,  0.00000000e+00, -2.14437988e+03,
#         -3.99871997e+03,  7.35899963e+01, -9.81991664e-02,  3.01087469e-01,
#          9.37860429e-01, -1.41848624e-01, -1.57937000e+03, -8.21900024e+02,
#         -1.47309998e+02,  1.85990005e+02,  9.36500015e+01, -2.19999999e-01],
#        dtype=float32)]

# %%
class JsonToData:
    def __init__(self, fp, seconds_ago = 5):
        self.replay_data = self.load_json(fp)
        self.capture_size = self.replay_data['properties']['RecordFPS'] * seconds_ago
        self.keyframes = [keyframe_data['frame'] for keyframe_data in self.replay_data['keyframes']]
    
    
    def name_to_id(self, name: str) -> int:
        return self.replay_data['names'].index(name)
    
    @staticmethod
    def load_json(fp: str) -> dict:
        with open(fp, 'r') as file:
            return json.load(file)
        
    @staticmethod
    def to_recent_keyframe(frame: int) -> int:
        return min(keyframes, key=lambda keyframe: frame - keyframe if keyframe <= frame else float('inf'))

# %%
goals[1]['frame']
# Out:
# 2816

# %%
replay_data['network_frames']['frames'][2696]
# Out:
# {'time': 103.540184,
#  'delta': 0.0333337,
#  'new_actors': [],
#  'deleted_actors': [],
#  'updated_actors': [{'actor_id': 174,
#    'stream_id': 42,
#    'object_id': 59,
#    'attribute': {'RigidBody': {'sleeping': False,
#      'location': {'x': -2364.53, 'y': 4611.31, 'z': 16.97},
#      'rotation': {'x': 0.0018854814,
#       'y': 0.0041890596,
#       'z': -0.4515543,
#       'w': 0.8922318},
#      'linear_velocity': {'x': 784.99, 'y': -1217.24, 'z': 1.02},
#      'angular_velocity': {'x': 0.59, 'y': 0.29, 'z': 57.63}}}},
#   {'actor_id': 174,
#    'stream_id': 50,
#    'object_id': 299,
#    'attribute': {'Byte': 98}},
#   {'actor_id': 148,
#    'stream_id': 42,
#    'object_id': 59,
#    'attribute': {'RigidBody': {'sleeping': False,
#      'location': {'x': -3690.2, 'y': 937.96, 'z': 573.44},
#      'rotation': {'x': 0.7264567,
#       'y': 0.56021667,
#       'z': 0.31311247,
#       'w': 0.24572042},
#      'linear_velocity': {'x': -2130.4, 'y': -2042.91, 'z': -241.51},
#      'angular_velocity': {'x': -354.08, 'y': 161.93, 'z': 456.5}}}},
#   {'actor_id': 139,
#    'stream_id': 51,
#    'object_id': 300,
#    'attribute': {'Byte': 230}}]}
